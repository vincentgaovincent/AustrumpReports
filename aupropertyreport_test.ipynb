# %%
import os    
from dotenv  import load_dotenv
from pathlib import Path
import requests

# %%
load_dotenv(dotenv_path = Path("C:/Users/Leon/API_keys/.env"))
auproperty_api=os.getenv('auproperty_vincent')
type(auproperty_api)
# Out:
# str

# %% [markdown]
# # Access Token:

# %%
auth_url = 'https://api2.aupropertyreport.com/api/auth'

auth_response = requests.post(auth_url, data = {
                        'email':"leon20130301@hotmail.com",
                        'api_key':auproperty_api,
                        })
auth_token = auth_response.json() 
access_token = auth_token['data']["token"]
auth = {"Authorization":"Bearer " + access_token}
auth
# Out:
# {'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..e1z0nOFzdYWQhGExBuqhHkMkbGLBWcg6qbo4C4n7ZBk'}

# %% [markdown]
# # Property Search: Townhouse

# %% [markdown]
# 3/17 Hillcrest Avenue, Chadstone Vic 3148
#
# "https://api2.aupropertyreport.com/api/property/search?q=3+17+hillcrest+ave+chadstone+vic+3148"
#
# OR
#
# "https://api2.aupropertyreport.com/api/property/search?q=3+17+hillcrest+ave+chadstone"
#
# 都可以

# %%
property_search_url = "https://api2.aupropertyreport.com/api/property/search?q=3+17+hillcrest+ave+chadstone+vic+3148"

# GET Request
property_search_request = requests.get(property_search_url,headers=auth,params={"limit":"50"})
property_search_respond = property_search_request.json()
property_search_respond
# Out:
# [{'address': '3/17 Hillcrest Avenue, Chadstone Vic 3148',
#   'code': 'unit-3-17-hillcrest-ave-chadstone-vic-3148',
#   'state': 'VIC',
#   'suburb': 'Chadstone',
#   'postcode': '3148'}]

# %% [markdown]
# 非常注意： New Test:

# %% [markdown]
# 27A Fermanagh Road, Camberwell VIC 3124
#
# 15-15A Ian GroveBurwood VIC 3125

# %%
property_search_url = "https://api2.aupropertyreport.com/api/property/search?q=27A+Fermanagh+Road+Camberwell+vic+3124"

# GET Request
property_search_request = requests.get(property_search_url,headers=auth,params={"limit":"50"})
property_search_respond = property_search_request.json()
property_search_respond
# Out:
# []

# %%
property_search_url = "https://api2.aupropertyreport.com/api/property/search?q=15+15A+Ian+GroveBurwood+vic+3125"

# GET Request
property_search_request = requests.get(property_search_url,headers=auth,params={"limit":"50"})
property_search_respond = property_search_request.json()
property_search_respond
# Out:
# []

# %%
type(property_search_respond)
# Out:
# list

# %%
property_search_url = "https://api2.aupropertyreport.com/api/property/search?q=15+15A+Ian+Grove+Burwood+vic+3125"

# GET Request
property_search_request = requests.get(property_search_url,headers=auth,params={"limit":"50"})
property_search_respond = property_search_request.json()
property_search_respond
# Out:
# [{'address': '15A Ian Grove, Burwood Vic 3125',
#   'code': '15a-ian-gr-burwood-vic-3125',
#   'state': 'VIC',
#   'suburb': 'Burwood',
#   'postcode': '3125'},
#  {'address': '15-15A Ian Grove, Burwood Vic 3125',
#   'code': '15-15a-ian-gr-burwood-vic-3125',
#   'state': 'VIC',
#   'suburb': 'Burwood',
#   'postcode': '3125'}]

# %% [markdown]
# ### 特殊情况 -- 地址含有三个数字：

# %% [markdown]
# 3/36-38 Morton Street, Clayton, Vic 3168 - Realestate

# %%
property_search_url = "https://api2.aupropertyreport.com/api/property/search?q=3+36+38+Morton+Street+Clayton +vic+3168"

# GET Request
property_search_request = requests.get(property_search_url,headers=auth,params={"limit":"50"})
property_search_respond = property_search_request.json()
property_search_respond
# Out:
# [{'address': '3/36-38 Morton Street, Clayton Vic 3168',
#   'code': 'unit-3-36-38-morton-st-clayton-vic-3168',
#   'state': 'VIC',
#   'suburb': 'Clayton',
#   'postcode': '3168'}]

# %% [markdown]
# # Property History:

# %% [markdown]
# ### Townhouse Example: PS：可能有missing data ie.房间数

# %% [markdown]
# unit-3-36-38-morton-st-clayton-vic-3168/history
#
# unit-3-17-hillcrest-ave-chadstone-vic-3148/history

# %%
property_history_url = "https://api2.aupropertyreport.com/api/property/unit-3-36-38-morton-st-clayton-vic-3168/history"

# GET Request
property_history_request = requests.get(property_history_url,headers=auth,params={"limit":"50"})
property_history_respond=property_history_request.json()
property_history_respond
# Out:
# {'data': {'state': 'VIC',
#   'address_code': 'unit-3-36-38-morton-st-clayton-vic-3168',
#   'gnaf_pid': 'GAVIC423282883',
#   'address': '3/36-38 Morton Street',
#   'suburb_code': 'clayton-vic-3168',
#   'suburb_name': 'Clayton',
#   'postcode': '3168',
#   'sa2_code': 212051320,
#   'lat': -37.9177252,
#   'lng': 145.1388809,
#   'image': 'https://www.aupropertyreport.com/public/assets/img/not_available.png',
#   'og_image': '',
#   'type': 'unit',
#   'property_type': 'unit',
#   'bed': 3,
#   'bath': 1,
#   'car': 1,
#   'land': '',
#   'building': 0,
#   'year_built': 0,
#   'lot_plan': '',
#   'history': {'data': [{'event': 'Rent',
#      'date': '2013-02-19',
#      'price': 330,
#      'agency': 'Harcourts - Clayton'},
#     {'event': 'Rent',
#      'date': '2012-09-07',
#      'price': 330,
#      'agency': 'Harcourts - Clayton'},
#     {'event': 'Rent',
#      'date': '2011-06-12',
#      'price': 340,
#      'agency': 'Harcourts - Clayton'},
#     {'event': 'Rent',
# ...

# %% [markdown]
# ### House Example:

# %%
property_history_url = "https://api2.aupropertyreport.com/api/property/4-Gaynor-Cres-glen-waverley-vic-3150/history"

# GET Request
property_history_request = requests.get(property_history_url,headers=auth,params={"limit":"50"})
property_history_respond=property_history_request.json()
property_history_respond
# Out:
# {'data': {'state': 'VIC',
#   'address_code': '4-gaynor-cres-glen-waverley-vic-3150',
#   'gnaf_pid': 'GAVIC421867883',
#   'address': '4 Gaynor Cres',
#   'suburb_code': 'glen-waverley-vic-3150',
#   'suburb_name': 'Glen Waverley',
#   'postcode': '3150',
#   'sa2_code': 212051321,
#   'lat': -37.866498,
#   'lng': 145.177738,
#   'image': 'https://i7.auhouseprices.com/img/QTdwTnorM3VoQjZaUE9KRkcwZWpEYzBTZW5ERnRSbzlyRHlGZXRUTlpCeEpBMGo0dTg3eTRmbDVyUGs3ckZSNUZiUjdNTnpLYkNJTDRnOFMwVFpZckVrTmk3VXpoZVN6Y0RIU2VGaVB2NWdrSG5IckIvcWtGSWQ2bVNUSlRsUmh3Y0RxNGo4Vk1wRk9XazZwOUFFUUVvalFQQjl5QjlRVXNtcThieGh6WHBzPQ/preview.jpg',
#   'og_image': '',
#   'type': 'house',
#   'property_type': 'house',
#   'bed': 4,
#   'bath': 2,
#   'car': 2,
#   'land': '652',
#   'building': 211,
#   'year_built': 1975,
#   'lot_plan': '142/LP91008',
#   'history': {'data': [{'event': 'Sold',
#      'date': '2020-06-20',
#      'price': 1120000,
#      'agency': 'Axis Property - CAULFIELD'},
# ...

# %%
property_history=property_history_respond['data']['history']['data']
property_history
# Out:
# [{'event': 'Sold',
#   'date': '2017-06-02',
#   'price': 1800000,
#   'agency': 'Llc Real Estate - Mount Waverley'},
#  {'event': 'Sold', 'date': '2002-04-27', 'price': 322000},
#  {'event': 'Sold', 'date': '1990-04-24', 'price': 173000},
#  {'event': 'Sold', 'date': '1982-05-08', 'price': 53600},
#  {'event': 'Sold', 'date': '1981-05-14', 'price': 61000}]

# %%
type(property_history)
# Out:
# list

# %%
property_history[0]
# Out:
# {'event': 'Sold',
#  'date': '2017-06-02',
#  'price': 1800000,
#  'agency': 'Llc Real Estate - Mount Waverley'}

# %%
property_history[0]['event']
# Out:
# 'Sold'

# %%
property_history[0]['date']
# Out:
# '2017-06-02'

# %%
property_history[0]['price']
# Out:
# 1800000

# %% [markdown]
# # Property Nearby Schools:

# %% [markdown]
# This endpoint retrieves property detail and nearby schools.

# %%
'''
curl "/api/property/12a-doyle-st-avondale-heights-vic-3034/nearby-schools"
  -H "Authorization: Bearer TOKEN"
'''

# %%
property_school_url = "https://api2.aupropertyreport.com/api/property/5-cherry-st-glen-waverley-vic-3150/nearby-schools"

# GET Request
property_school_request = requests.get(property_school_url,headers=auth,params={"limit":"50"})
property_school_respond=property_school_request.json()
property_school_respond
# Out:
# {'data': {'state': 'VIC',
#   'address_code': '5-cherry-st-glen-waverley-vic-3150',
#   'gnaf_pid': 'GAVIC421572019',
#   'address': '5 Cherry Street',
#   'suburb_code': 'glen-waverley-vic-3150',
#   'suburb_name': 'Glen Waverley',
#   'postcode': '3150',
#   'sa2_code': 212051322,
#   'lat': -37.865311,
#   'lng': 145.150734,
#   'image': 'https://i7.auhouseprices.com/img/QTdwTnorM3VoQjZaUE9KRkcwZWpEYzBTZW5ERnRSbzlyRHlGZXRUTlpCeWVwNjNYdEt6eXJiR25jblFLS3BGaGxWSEJRMU5Zc1VwQmdISmJ5RGRXdFpGbE02Um5mdzZpOG92a1BpdEh2NWVqU0FXZi9ia1pJSi9HVmg3NXNEM01CUWg0Y2dHQklhcnhRQnFCZ3d0eE9UQ0hodDRXaFJiNVlGc1JRMllYdEFjPQ/preview.jpg',
#   'og_image': '',
#   'type': 'house',
#   'property_type': 'house',
#   'bed': 5,
#   'bath': 3,
#   'car': 2,
#   'land': '650',
#   'building': 524,
#   'year_built': 2009,
#   'lot_plan': '',
#   'nearby_schools': {'data': [{'school_name': "St Christopher's School",
#      'school_note': 'Catholic Coeducational School',
#      'state': 'VIC',
# ...

# %% [markdown]
# # Similar Sold Properties: 不止一页！！！！ 714个？？太多了吧

# %% [markdown]
# #### This endpoint retrieves property detail and `comparable` sold properties.

# %% [markdown]
# ### PS: 过去一年内，10个相似 SOLD 物业，我觉得是房间数量为主，面积大小，位置（坐标）
#
# ### PS：非常注意，例如 4 Riviera Street MT Waverley --- RP data 没有出售价格，但aupropertyreport有 ！！！！！
#
# ### PS: 提供了与 RP data不一样的数据！！！！！

# %%
'''
curl "/api/property/12a-doyle-st-avondale-heights-vic-3034/similar-sold"
  -H "Authorization: Bearer TOKEN"
'''

# %%
similar_sold_url = "https://api2.aupropertyreport.com/api/property/5-cherry-st-glen-waverley-vic-3150/similar-sold"

# GET Request
similar_sold_request = requests.get(similar_sold_url,headers=auth,params={"limit":"50"})
similar_sold_respond=similar_sold_request.json()
similar_sold_respond
# Out:
# {'data': {'state': 'VIC',
#   'address_code': '5-cherry-st-glen-waverley-vic-3150',
#   'gnaf_pid': 'GAVIC421572019',
#   'address': '5 Cherry Street',
#   'suburb_code': 'glen-waverley-vic-3150',
#   'suburb_name': 'Glen Waverley',
#   'postcode': '3150',
#   'sa2_code': 212051322,
#   'lat': -37.865311,
#   'lng': 145.150734,
#   'image': 'https://i7.auhouseprices.com/img/QTdwTnorM3VoQjZaUE9KRkcwZWpEYzBTZW5ERnRSbzlyRHlGZXRUTlpCeWVwNjNYdEt6eXJiR25jblFLS3BGaGxWSEJRMU5Zc1VwQmdISmJ5RGRXdFpGbE02Um5mdzZpOG92a1BpdEh2NWVqU0FXZi9ia1pJSi9HVmg3NXNEM01CUWg0Y2dHQklhcnhRQnFCZ3d0eE9UQ0hodDRXaFJiNVlGc1JRMllYdEFjPQ/preview.jpg',
#   'og_image': '',
#   'type': 'house',
#   'property_type': 'house',
#   'bed': 5,
#   'bath': 3,
#   'car': 2,
#   'land': '650',
#   'building': 524,
#   'year_built': 2009,
#   'lot_plan': '',
#   'similar_sold': {'data': [{'state': 'VIC',
#      'address': '3 Lincoln Street',
#      'suburb_code': 'burwood-east-vic-3151',
#      'suburb_name': 'Burwood East',
# ...

# %% [markdown]
# # Property Sale-O-Meter: 类似5房 2KM 年 中价位

# %% [markdown]
# This endpoint retrieves property detail and sale-o-meter. 是类似5房，过去一年， 半径2KM的，统计一年的中价位。

# %%
'''
curl "/api/property/12a-doyle-st-avondale-heights-vic-3034/saleometer"
  -H "Authorization: Bearer TOKEN"
'''

# %%
property_sold_meter_url = "https://api2.aupropertyreport.com/api/property/5-cherry-st-glen-waverley-vic-3150/saleometer"

# GET Request
property_sold_meter_request = requests.get(property_sold_meter_url,headers=auth,params={"limit":"50"})
property_sold_meter_respond=property_sold_meter_request.json()
property_sold_meter_respond
# Out:
# {'data': {'state': 'VIC',
#   'address_code': '5-cherry-st-glen-waverley-vic-3150',
#   'gnaf_pid': 'GAVIC421572019',
#   'address': '5 Cherry Street',
#   'suburb_code': 'glen-waverley-vic-3150',
#   'suburb_name': 'Glen Waverley',
#   'postcode': '3150',
#   'sa2_code': 212051322,
#   'lat': -37.865311,
#   'lng': 145.150734,
#   'image': 'https://i7.auhouseprices.com/img/QTdwTnorM3VoQjZaUE9KRkcwZWpEYzBTZW5ERnRSbzlyRHlGZXRUTlpCeWVwNjNYdEt6eXJiR25jblFLS3BGaGxWSEJRMU5Zc1VwQmdISmJ5RGRXdFpGbE02Um5mdzZpOG92a1BpdEh2NWVqU0FXZi9ia1pJSi9HVmg3NXNEM01CUWg0Y2dHQklhcnhRQnFCZ3d0eE9UQ0hodDRXaFJiNVlGc1JRMllYdEFjPQ/preview.jpg',
#   'og_image': '',
#   'type': 'house',
#   'property_type': 'house',
#   'bed': 5,
#   'bath': 3,
#   'car': 2,
#   'land': '650',
#   'building': 524,
#   'year_built': 2009,
#   'lot_plan': '',
#   'saleometer': {'data': {'price_sum': 223586052,
#     'price_avg': 2129391,
#     'price_median': 1905000,
#     'standard_deviation': 994306,
#     'price_min': 1021000,
# ...

# %% [markdown]
# # Property Sold Trend Data：类似5房，半径2km 月 中价位

# %% [markdown]
# This endpoint retrieves property detail and sold trend data. PS: 过去一年，类似5房，半径2KM，统计一年每个月的中价位。

# %%
'''
curl "/api/property/12a-doyle-st-avondale-heights-vic-3034/sold-trend-data"
  -H "Authorization: Bearer TOKEN"
'''

# %%
property_sold_trend_url = "https://api2.aupropertyreport.com/api/property/5-cherry-st-glen-waverley-vic-3150/sold-trend-data"

# GET Request
property_sold_trend_request = requests.get(property_sold_trend_url,headers=auth,params={"limit":"50"})
property_sold_trend_respond = property_sold_trend_request.json()
property_sold_trend_respond
# Out:
# {'data': {'state': 'VIC',
#   'address_code': '5-cherry-st-glen-waverley-vic-3150',
#   'gnaf_pid': 'GAVIC421572019',
#   'address': '5 Cherry Street',
#   'suburb_code': 'glen-waverley-vic-3150',
#   'suburb_name': 'Glen Waverley',
#   'postcode': '3150',
#   'sa2_code': 212051322,
#   'lat': -37.865311,
#   'lng': 145.150734,
#   'image': 'https://i7.auhouseprices.com/img/QTdwTnorM3VoQjZaUE9KRkcwZWpEYzBTZW5ERnRSbzlyRHlGZXRUTlpCeWVwNjNYdEt6eXJiR25jblFLS3BGaGxWSEJRMU5Zc1VwQmdISmJ5RGRXdFpGbE02Um5mdzZpOG92a1BpdEh2NWVqU0FXZi9ia1pJSi9HVmg3NXNEM01CUWg0Y2dHQklhcnhRQnFCZ3d0eE9UQ0hodDRXaFJiNVlGc1JRMllYdEFjPQ/preview.jpg',
#   'og_image': '',
#   'type': 'house',
#   'property_type': 'house',
#   'bed': 5,
#   'bath': 3,
#   'car': 2,
#   'land': '650',
#   'building': 524,
#   'year_built': 2009,
#   'lot_plan': '',
#   'sold_trend_data': {'data': {'investor_metrics': {'median_price': 1912500,
#      'median_price_12_months_ago': 1711000,
#      'annual_growth_last_12_months': 0.1178},
# ...

# %% [markdown]
# # Property Sold Trend: Townhouse Example Test PS：数据不完整，读不出 房间数！

# %% [markdown]
# 3/17 Hillcrest Avenue, Chadstone Vic 3148

# %%
property_sold_trend_url = "https://api2.aupropertyreport.com/api/property/unit-3-17-hillcrest-ave-chadstone-vic-3148/sold-trend-data"

# GET Request
property_sold_trend_request = requests.get(property_sold_trend_url,headers=auth,params={"limit":"50"})
property_sold_trend_respond=property_sold_trend_request.json()
property_sold_trend_respond
# Out:
# {'data': {'state': 'VIC',
#   'address_code': 'unit-3-17-hillcrest-ave-chadstone-vic-3148',
#   'gnaf_pid': 'GAVIC719223185',
#   'address': '3/17 Hillcrest Avenue',
#   'suburb_code': 'chadstone-vic-3148',
#   'suburb_name': 'Chadstone',
#   'postcode': '3148',
#   'sa2_code': 212051319,
#   'lat': -37.8885424,
#   'lng': 145.1054838,
#   'image': 'https://www.aupropertyreport.com/public/assets/img/not_available.png',
#   'og_image': '',
#   'type': 'unit',
#   'property_type': 'unit',
#   'bed': 0,
#   'bath': 0,
#   'car': 0,
#   'land': '',
#   'building': 0,
#   'year_built': 0,
#   'lot_plan': '',
#   'sold_trend_data': {'data': {'investor_metrics': {'median_price': 0,
#      'annual_growth_last_12_months': ''},
#     'invested_performance': {'2021-02': 100,
#      '2021-03': 100,
#      '2021-04': 100,
#      '2021-05': 94.12,
#      '2021-06': 88.24,
#      '2021-07': 88.24,
#      '2021-08': 95.96,
#      '2021-09': 95.96,
#      '2021-10': 153.68,
#      '2021-11': 153.68,
# ...

# %% [markdown]
# # Suburb For Sale Properties: 不止一页！ 197个  含Days on the market

# %% [markdown]
# This endpoint retrieves properties listed as for sale in the suburb.

# %% [markdown]
# `PS: QQ： 现在 GLEN 才11个在售物业？？？？？？ days_on_market 还有 ZERO的？？？？？`

# %%
'''
curl "/api/suburb/avondale-heights-vic-3034/buy"
  -H "Authorization: Bearer TOKEN"
  
'''

# %%
for_sale_url = "https://api2.aupropertyreport.com/api/suburb/glen-waverley-vic-3150/buy"

# GET Request
for_sale_request = requests.get(for_sale_url,headers=auth,params={"limit":"50"})
for_sale_respond=for_sale_request.json()
for_sale_respond
# Out:
# {'data': {'id': 1810,
#   'state': 'VIC',
#   'name': 'Glen Waverley',
#   'postcode': '3150',
#   'suburb_code': 'glen-waverley-vic-3150',
#   'suburb_name': 'Glen Waverley VIC 3150',
#   'buy': {'data': [{'state': 'VIC',
#      'address': '701/39 Kingsway',
#      'suburb_code': 'glen-waverley-vic-3150',
#      'suburb_name': 'Glen Waverley',
#      'postcode': '3150',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUmJUazBzc2JReUZxZDNhM3IvSFZKSjM3YjNkbEdxMEM0YmRPSkEwcTNaTFdZOENkRHhWWHV0MnJjZXBURkpiV2JGczNOYWFtM0lOdGxzbi9MOXZ1WWt3VEZtUVBWVEUzUTdRc0Z3NXJ2amp3PT0/preview.jpg',
#      'type': 'apartment',
#      'bed': 2,
#      'bath': 2,
#      'car': 1,
#      'lat': -37.8798697,
#      'lng': 145.1636838,
#      'land': '',
#      'list_date': '2022-03-21',
#      'list_price': '$490,000 - $535,000',
#      'days_on_market': 1,
#      'gnaf_pid': 'GAVIC425020160',
#      'pu_id': 19783906361,
# ...

# %%
for_sale_url_2 = "https://api2.aupropertyreport.com/api/suburb/glen-waverley-vic-3150/buy?page=19"

# GET Request
for_sale_request_2 = requests.get(for_sale_url_2,headers=auth,params={"limit":"50"})
for_sale_respond_2=for_sale_request_2.json()
for_sale_respond_2
# Out:
# {'data': {'id': 1810,
#   'state': 'VIC',
#   'name': 'Glen Waverley',
#   'postcode': '3150',
#   'suburb_code': 'glen-waverley-vic-3150',
#   'suburb_name': 'Glen Waverley VIC 3150',
#   'buy': {'data': [{'state': 'VIC',
#      'address': '13 Wilson Road',
#      'suburb_code': 'glen-waverley-vic-3150',
#      'suburb_name': 'Glen Waverley',
#      'postcode': '3150',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQVFkvOTYwbE5UbS9pci9iUmhzOGFGeTVqbUJGNE82UjdScHlIZk1kbkRVdlpzL2dMOFB0Q2VEQXFRMEVrdForRndab2E0eXZWZ04waGozdkd3clJzaTliMEhvZFNjVTZqMlhGdVJNY2s1T2VRPT0/preview.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 2,
#      'car': 2,
#      'lat': -37.885428,
#      'lng': 145.167651,
#      'land': '711',
#      'list_date': '2021-09-12',
#      'list_price': '',
#      'days_on_market': 186,
#      'gnaf_pid': 'GAVIC420091308',
#      'pu_id': 19730783186,
#      'agent_code': 'VIC168106'},
# ...

# %% [markdown]
# # Suburb Sold Properties: 不止一页！！！！！824个

# %% [markdown]
# This endpoint retrieves properties sold within last 30 days in the suburb.

# %% [markdown]
# `QQ：没有20 Cherry???`

# %%
'''
curl "/api/suburb/avondale-heights-vic-3034/sold"
  -H "Authorization: Bearer TOKEN"
'''

# %%
sold_url = "https://api2.aupropertyreport.com/api/suburb/glen-waverley-vic-3150/sold"

# GET Request
sold_request = requests.get(sold_url,headers=auth,params={"limit":"50"})
sold_respond=sold_request.json()
sold_respond
# Out:
# {'data': {'id': 1810,
#   'state': 'VIC',
#   'name': 'Glen Waverley',
#   'postcode': '3150',
#   'suburb_code': 'glen-waverley-vic-3150',
#   'suburb_name': 'Glen Waverley VIC 3150',
#   'sold': {'data': [{'state': 'VIC',
#      'address': '10 Westlands Road',
#      'suburb_code': 'glen-waverley-vic-3150',
#      'suburb_name': 'Glen Waverley',
#      'postcode': '3150',
#      'image': 'https://farm66.static.flickr.com/65535/51939549184_6d634ff05d.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 2,
#      'car': 1,
#      'lat': -37.870877,
#      'lng': 145.179449,
#      'land': '661',
#      'sold_date': '2022-03-13',
#      'sold_price': 1438000,
#      'gnaf_pid': 'GAVIC419781839',
#      'pu_id': 39760140130,
#      'agent_code': 'VIC304737',
#      'sold_price_display': '$1,410,000 - $1,478,000'},
#     {'state': 'VIC',
#      'address': '33 Johnson Drive',
#      'suburb_code': 'glen-waverley-vic-3150',
#      'suburb_name': 'Glen Waverley',
# ...

# %%
sold_url_2 = "https://api2.aupropertyreport.com/api/suburb/glen-waverley-vic-3150/sold?page=2"

# GET Request
sold_request_2 = requests.get(sold_url_2,headers=auth,params={"limit":"50"})
sold_respond_2=sold_request_2.json()
sold_respond_2

# %% [markdown]
# # Suburb Sold Trend: 区域 每个月 中价位

# %% [markdown]
# This endpoint retrieves suburb detail and sold trend data. PS：过去一年，每个月，中价位统计。

# %%
'''
curl "/api/suburb/avondale-heights-vic-3034/sold-trend-data"
  -H "Authorization: Bearer TOKEN"
'''

# %%
sold_trend_url = "https://api2.aupropertyreport.com/api/suburb/glen-waverley-vic-3150/sold-trend-data"

# GET Request
sold_trend_request = requests.get(sold_trend_url,headers=auth,params={"limit":"50"})
sold_trend_respond=sold_trend_request.json()
sold_trend_respond
# Out:
# {'data': {'id': 1810,
#   'state': 'VIC',
#   'name': 'Glen Waverley',
#   'postcode': '3150',
#   'suburb_code': 'glen-waverley-vic-3150',
#   'suburb_name': 'Glen Waverley VIC 3150',
#   'sold_trend_data': {'data': {'investor_metrics': {'median_price': 1650000,
#      'median_price_12_months_ago': 1400000,
#      'annual_growth_last_12_months': 0.1786},
#     'invested_performance': {'2021-02': 100,
#      '2021-03': 102.79,
#      '2021-04': 104.1,
#      '2021-05': 110.76,
#      '2021-06': 110.87,
#      '2021-07': 113.66,
#      '2021-08': 115.27,
#      '2021-09': 117.47,
#      '2021-10': 118.12,
#      '2021-11': 120.19,
#      '2021-12': 120.12,
#      '2022-01': 119.9,
#      '2022-02': 121.15},
#     'median_price': {'2021-02': 1362000,
#      '2021-03': 1400000,
#      '2021-04': 1417800,
#      '2021-05': 1508500,
#      '2021-06': 1510000,
#      '2021-07': 1548000,
#      '2021-08': 1570000,
#      '2021-09': 1600000,
#      '2021-10': 1608750,
# ...

# %% [markdown]
# # Suburb Median Sale Price：同上，但是 是 summary

# %% [markdown]
# This endpoint retrieves suburb detail and median sale price. 过去一年，每个月，中价位，LIST。

# %%
'''
curl "/api/suburb/avondale-heights-vic-3034/median-sale-price"
  -H "Authorization: Bearer TOKEN"
'''

# %%
median_sale_url = "https://api2.aupropertyreport.com/api/suburb/glen-waverley-vic-3150/median-sale-price"

# GET Request
median_sale_request = requests.get(median_sale_url,headers=auth,params={"limit":"50"})
median_sale_respond=median_sale_request.json()
median_sale_respond
# Out:
# {'data': {'id': 1810,
#   'state': 'VIC',
#   'name': 'Glen Waverley',
#   'postcode': '3150',
#   'suburb_code': 'glen-waverley-vic-3150',
#   'suburb_name': 'Glen Waverley VIC 3150',
#   'median_sale_price': {'data': {'2021-03-31': 1400000,
#     '2021-04-30': 1415000,
#     '2021-05-31': 1508500,
#     '2021-06-30': 1510000,
#     '2021-07-31': 1548000,
#     '2021-08-31': 1570000,
#     '2021-09-30': 1600000,
#     '2021-10-31': 1607500,
#     '2021-11-30': 1637000,
#     '2021-12-31': 1635000,
#     '2022-01-31': 1633000,
#     '2022-02-28': 1650000}}}}

# %% [markdown]
# # Suburb Sale-O-Meter: 区域 年 中价位

# %% [markdown]
# This endpoint retrieves suburb detail and sale-o-meter. PS: 这是整个区域的 一年的，VS 对比上面 Property Section的是类似物业 半径2KM的统计。

# %%
'''
curl "/api/suburb/avondale-heights-vic-3034/saleometer"
  -H "Authorization: Bearer TOKEN"
'''

# %%
sold_meter_url = "https://api2.aupropertyreport.com/api/suburb/glen-waverley-vic-3150/saleometer"

# GET Request
sold_meter_request = requests.get(sold_meter_url,headers=auth,params={"limit":"50"})
sold_meter_respond=sold_meter_request.json()
sold_meter_respond
# Out:
# {'data': {'id': 1810,
#   'state': 'VIC',
#   'name': 'Glen Waverley',
#   'postcode': '3150',
#   'suburb_code': 'glen-waverley-vic-3150',
#   'suburb_name': 'Glen Waverley VIC 3150',
#   'saleometer': {'data': {'price_sum': 824933905,
#     'price_avg': 1611200,
#     'price_median': 1520000,
#     'standard_deviation': 828634,
#     'price_min': 252500,
#     'price_10th': 900300,
#     'price_20th': 1145000,
#     'price_25th': 1248750,
#     'price_30th': 1296500,
#     'price_40th': 1402400,
#     'price_50th': 1520000,
#     'price_60th': 1622400,
#     'price_70th': 1743800,
#     'price_75th': 1826250,
#     'price_80th': 1920000,
#     'price_90th': 2359100,
#     'price_max': 11500000,
#     'num_all': 747,
#     'num_all_with_price': 512,
#     'start_date': '2021-03-01',
#     'end_date': '2022-03-01',
#     'filter': {'suburb_id': 1810, 'updated': '2022-03-16'}}}}}

# %% [markdown]
# # Suburb Sale Stats: 暂时 不理解

# %% [markdown]
# This endpoint retrieves suburb detail and sale market trend.

# %% [markdown]
# ### PS： 注意有 Suburb Address Count!!!

# %% [markdown]
# `QQ: for_sale_active_volume_12m 是什么？？？`

# %%
'''
curl "/api/suburb/avondale-heights-vic-3034/sale-stats"
  -H "Authorization: Bearer TOKEN"
'''

# %%
sell_states_url = "https://api2.aupropertyreport.com/api/suburb/glen-waverley-vic-3150/sale-stats"

# GET Request
sell_states_request = requests.get(sell_states_url,headers=auth,params={"limit":"50"})
sell_states_respond=sell_states_request.json()
sell_states_respond
# Out:
# {'data': {'id': 1810,
#   'state': 'VIC',
#   'name': 'Glen Waverley',
#   'postcode': '3150',
#   'suburb_code': 'glen-waverley-vic-3150',
#   'suburb_name': 'Glen Waverley VIC 3150',
#   'sale_stats': {'data': {'property_type': 'house',
#     'address_count': 14095,
#     'median_bed_count': 4,
#     'median_bath_count': 2,
#     'median_car_count': 2,
#     'for_sale_new_volume_1m': 54,
#     'for_sale_new_volume_3m': 107,
#     'for_sale_new_volume_6m': 342,
#     'for_sale_new_volume_12m': 646,
#     'for_sale_active_volume_1m': 92,
#     'for_sale_active_volume_3m': 71,
#     'for_sale_active_volume_6m': 83,
#     'for_sale_active_volume_12m': 86,
#     'for_sale_dom_median_12m': 29,
#     'for_sale_discount_median_12m': '15.0',
#     'for_sale_median_list_price_12m': 1783650,
#     'sale_volume_12m': 541,
#     'sale_volume_12m_yip': 516,
#     'sale_turnover_12m': '3.8',
#     'sale_sum_12m': 683179980,
#     'sale_minimum_12m': 900000,
#     'sale_maximum_12m': 11500000,
# ...

# %% [markdown]
# # Suburb Auction Results: 不止一页！144个 = 30 天+ eg.PS 2021 Oct, house and TH; 含 PASS IN etc！

# %% [markdown]
# This endpoint retrieves auction results within last 30 days in the suburb.

# %% [markdown]
# 'Sold',
#
# 'Passed In',
#
# 'Private Sale',
#
# 'Withdrawn Prior To Auction',

# %% [markdown]
# `QQ: 但没有 20 cherry!!!!!!!!!`

# %%
'''
curl "/api/suburb/avondale-heights-vic-3034/auction-results"
  -H "Authorization: Bearer TOKEN"
'''
# Out:
# '\ncurl "/api/suburb/avondale-heights-vic-3034/auction-results"\n  -H "Authorization: Bearer TOKEN"\n'

# %%
auction_results_url = "https://api2.aupropertyreport.com/api/suburb/glen-waverley-vic-3150/auction-results"

# GET Request
auction_result_request = requests.get(auction_results_url,headers=auth,params={"limit":"50"})
auction_result_respond=auction_result_request.json()
auction_result_respond
# Out:
# {'data': {'id': 1810,
#   'state': 'VIC',
#   'name': 'Glen Waverley',
#   'postcode': '3150',
#   'suburb_code': 'glen-waverley-vic-3150',
#   'suburb_name': 'Glen Waverley VIC 3150',
#   'auction_results': {'data': [{'id': 421774013,
#      'address': '25 Eastleigh Dr',
#      'state': 'VIC',
#      'suburb_name': 'Glen Waverley',
#      'postcode': '3150',
#      'type': 'house',
#      'bed': 4,
#      'sold_date': '2022-03-12',
#      'price': 1545000,
#      'result': 'Sold',
#      'is_sold': True,
#      'agency': 'Barry Plant Monash',
#      'pu_id': 39741654930},
#     {'id': 421484013,
#      'address': '35 Gauntlet Av',
#      'state': 'VIC',
#      'suburb_name': 'Glen Waverley',
#      'postcode': '3150',
#      'type': 'house',
#      'bed': 4,
#      'sold_date': '2022-03-12',
#      'price': 1538000,
#      'result': 'Sold',
#      'is_sold': True,
#      'agency': 'Barry Plant Monash',
#      'pu_id': 39743790641},
#     {'id': 421194013,
# ...

# %%
auction_results_url_2 = "https://api2.aupropertyreport.com/api/suburb/glen-waverley-vic-3150/auction-results?page=7"

# GET Request
auction_result_request_2 = requests.get(auction_results_url_2,headers=auth,params={"limit":"50"})
auction_result_respond_2=auction_result_request_2.json()
auction_result_respond_2
# Out:
# {'data': {'id': 1810,
#   'state': 'VIC',
#   'name': 'Glen Waverley',
#   'postcode': '3150',
#   'suburb_code': 'glen-waverley-vic-3150',
#   'suburb_name': 'Glen Waverley VIC 3150',
#   'auction_results': {'data': [{'id': 421228842,
#      'address': '2/2 Peveril St',
#      'state': 'VIC',
#      'suburb_name': 'Glen Waverley',
#      'postcode': '3150',
#      'type': 'townhouse',
#      'bed': 4,
#      'sold_date': '2021-12-04',
#      'price': 0,
#      'result': 'Withdrawn Prior To Auction',
#      'is_sold': False,
#      'agency': 'McGrath Waverley',
#      'pu_id': 19799774180},
#     {'id': 421928842,
#      'address': '17 Winmalee Dr',
#      'state': 'VIC',
#      'suburb_name': 'Glen Waverley',
#      'postcode': '3150',
#      'type': 'house',
#      'bed': 3,
#      'sold_date': '2021-12-04',
#      'price': 0,
#      'result': 'Sold Prior',
#      'is_sold': True,
#      'agency': 'Geoff Nixon Real Estate',
#      'pu_id': 39759045480},
#     {'id': 421638842,
# ...

# %%
auction_results_url_3 = "https://api2.aupropertyreport.com/api/suburb/glen-waverley-vic-3150/auction-results?page=15"

# GET Request
auction_result_request_3 = requests.get(auction_results_url_2,headers=auth,params={"limit":"50"})
auction_result_respond_3=auction_result_request_3.json()
auction_result_respond_3
# Out:
# {'data': {'id': 1810,
#   'state': 'VIC',
#   'name': 'Glen Waverley',
#   'postcode': '3150',
#   'suburb_code': 'glen-waverley-vic-3150',
#   'suburb_name': 'Glen Waverley VIC 3150',
#   'auction_results': {'data': [{'id': 421656860,
#      'address': '22 Tamarisk Av',
#      'state': 'VIC',
#      'suburb_name': 'Glen Waverley',
#      'postcode': '3150',
#      'type': 'house',
#      'bed': 4,
#      'sold_date': '2021-10-02',
#      'price': 1570000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'First National Quinta'},
#     {'id': 421366860,
#      'address': '561 Waverley Rd',
#      'state': 'VIC',
#      'suburb_name': 'Glen Waverley',
#      'postcode': '3150',
#      'type': 'house',
#      'bed': 4,
#      'sold_date': '2021-10-02',
#      'price': 1402000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'Biggin & Scott Glen Waverley'},
#     {'id': 421076860,
#      'address': '1/577 Waverley Rd',
# ...

# %% [markdown]
# # Suburb ABS data

# %% [markdown]
# This endpoint retrieves suburb Australian Bureau of Statistics data.

# %%
'''
curl "/api/suburb/avondale-heights-vic-3034/abs-data"
  -H "Authorization: Bearer TOKEN"
'''

# %%
abs_url = "https://api2.aupropertyreport.com/api/suburb/glen-waverley-vic-3150/abs-data"

# GET Request
abs_request = requests.get(abs_url,headers=auth,params={"limit":"50"})
abs_respond=abs_request.json()
abs_respond
# Out:
# {'data': {'id': 1810,
#   'state': 'VIC',
#   'name': 'Glen Waverley',
#   'postcode': '3150',
#   'suburb_code': 'glen-waverley-vic-3150',
#   'suburb_name': 'Glen Waverley VIC 3150',
#   'abs_data': {'data': {'medians_and_averages': {'median_age_persons': 40,
#      'median_mortgage_repay_monthly': 2000,
#      'median_personal_income_weekly': 561,
#      'median_rent_weekly': 430,
#      'median_family_income_weekly': 1778,
#      'average_num_psns_per_bedroom': '0.8',
#      'median_household_income_weekly': 1553,
#      'average_household_size': '2.9'},
#     'age': {'age_yr_0_4': 1738,
#      'age_yr_5_9': 2367,
#      'age_yr_10_19': 5711,
#      'age_yr_20_29': 5375,
#      'age_yr_30_39': 4590,
#      'age_yr_40_49': 5733,
#      'age_yr_50_59': 5124,
#      'age_yr_60_69': 4035,
#      'age_yr_70_plus': 5660},
#     'language_spoken_at_home': {'english': 16332,
#      'afrikaans': 43,
#      'arabic': 180,
#      'aindlng': 0,
#      'chinese': 11782,
# ...

# %% [markdown]
# # SA2 ABS data:

# %% [markdown]
# This endpoint retrieves SA2 Australian Bureau of Statistics data.

# %% [markdown]
# Step1: search Area Code:

# %%
'''
curl "/api/sa2/search?q=Keilor+East"
  -H "Authorization: Bearer TOKEN"
'''

# %%
sa2_areacode_url = "https://api2.aupropertyreport.com/api/sa2/search?q=glen+waverley"

# GET Request
sa2_areacode_request = requests.get(sa2_areacode_url,headers=auth,params={"limit":"50"})
sa2_areacode_respond=sa2_areacode_request.json()
sa2_areacode_respond
# Out:
# [{'id': 922,
#   'state': 'VIC',
#   'sa2_code': 212051321,
#   'sa2_name': 'Glen Waverley - East',
#   'sa3_code': '21205',
#   'sa3_name': 'Monash',
#   'sa4_code': '212',
#   'sa4_name': 'Melbourne - South East',
#   'gcc_code': 2,
#   'gcc_name': 'Greater Melbourne'},
#  {'id': 923,
#   'state': 'VIC',
#   'sa2_code': 212051322,
#   'sa2_name': 'Glen Waverley - West',
#   'sa3_code': '21205',
#   'sa3_name': 'Monash',
#   'sa4_code': '212',
#   'sa4_name': 'Melbourne - South East',
#   'gcc_code': 2,
#   'gcc_name': 'Greater Melbourne'},
#  {'id': 193,
#   'state': 'NSW',
#   'sa2_code': 110021190,
#   'sa2_name': 'Glen Innes',
#   'sa3_code': '11002',
#   'sa3_name': 'Inverell - Tenterfield',
#   'sa4_code': '110',
#   'sa4_name': 'New England and North West',
#   'gcc_code': 1,
#   'gcc_name': 'Rest of NSW'},
#  {'id': 728,
#   'state': 'VIC',
#   'sa2_code': 207011150,
#   'sa2_name': 'Glen Iris - East',
#   'sa3_code': '20701',
#   'sa3_name': 'Boroondara',
# ...

# %% [markdown]
# Step2: 根据 AREA CODE search 具体 Suburb

# %%
'''
curl "/api/sa2/212051321/abs-data"
  -H "Authorization: Bearer TOKEN"
'''

# %%
abs_sa2_url = "https://api2.aupropertyreport.com/api/sa2/212051321/abs-data"

# GET Request
abs_sa2_request = requests.get(abs_sa2_url,headers=auth,params={"limit":"50"})
abs_sa2_respond=abs_sa2_request.json()
abs_sa2_respond
# Out:
# {'data': {'id': 922,
#   'state': 'VIC',
#   'sa2_code': 212051321,
#   'sa2_name': 'Glen Waverley - East',
#   'sa3_code': '21205',
#   'sa3_name': 'Monash',
#   'sa4_code': '212',
#   'sa4_name': 'Melbourne - South East',
#   'gcc_code': 3,
#   'gcc_name': 'Greater Melbourne',
#   'area_sqkm': 9.1645,
#   'abs_data': {'data': {'medians_and_averages': {'median_age_persons': 42,
#      'median_mortgage_repay_monthly': 2000,
#      'median_personal_income_weekly': 569,
#      'median_rent_weekly': 441,
#      'median_family_income_weekly': 1799,
#      'average_num_psns_per_bedroom': '0.8',
#      'median_household_income_weekly': 1564,
#      'average_household_size': '2.9'},
#     'age': {'age_yr_0_4': 899,
#      'age_yr_5_9': 1296,
#      'age_yr_10_19': 2993,
#      'age_yr_20_29': 2481,
#      'age_yr_30_39': 2296,
#      'age_yr_40_49': 3003,
#      'age_yr_50_59': 2618,
#      'age_yr_60_69': 2312,
#      'age_yr_70_plus': 3189},
# ...

# %% [markdown]
# `QQ: 这两种方法数据不一致！！！`
# PS: 且这种，不包括，employment数据！！！！

# %% [markdown]
# # SUMMARY：

# %% [markdown]
# 1. ABS Data
#
# 2. Property History 可以！
#
# 3. Similar 物业数据，以及，类似物业表现trend统计，不错！
#
# 4. 其他统计数据，有待验证
#
# 5. 无 Valuation !!!!!
