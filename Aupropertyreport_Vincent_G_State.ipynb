# %%
import os    
from dotenv  import load_dotenv
from pathlib import Path
import requests
import pandas as pd
pd.options.display.max_colwidth = 600  # Set Full Display

# %% [markdown]
# vic, nsw, qld, sa, wa, act, nt, tas

# %%
state="vic"
suburb_search = state

# %%
date="2022-03-26"

# %% [markdown]
# ## First Key:

# %%
load_dotenv(dotenv_path = Path("C:/Users/Leon/API_keys/.env"))
auproperty_api=os.getenv('auproperty_vincent2')
type(auproperty_api)
# Out:
# str

# %%
auth_url = 'https://api2.aupropertyreport.com/api/auth'

auth_response = requests.post(auth_url, data = {
                        'email':"vincentgao076@gmail.com",
                        'api_key':auproperty_api,
                        })
auth_token = auth_response.json() 
access_token = auth_token['data']["token"]
auth = {"Authorization":"Bearer " + access_token}
auth
# Out:
# {'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..3opzibigM_hp8kksOdOwrSvWi-oLJOSOlKdIOI--a9k'}

# %% [markdown]
# ## Second Key:

# %%
# Overwrite, initiate second API key directly !!
# property_search_respond={}

# %%
property_search_url = "https://api2.aupropertyreport.com/api/property/search?q=3+17+hillcrest+ave+chadstone+vic+3148"

# GET Request
property_search_request = requests.get(property_search_url,headers=auth,params={"limit":"50"})
property_search_respond = property_search_request.json()
property_search_respond
# Out:
# [{'address': '3/17 Hillcrest Avenue, Chadstone Vic 3148',
#   'code': 'unit-3-17-hillcrest-ave-chadstone-vic-3148',
#   'state': 'VIC',
#   'suburb': 'Chadstone',
#   'postcode': '3148'}]

# %% [markdown]
# Exceed: {'message': 'You have exceeded your rate limit.', 'status_code': 429}
#
# Normal:  [{'address': '3/17 Hillcrest Avenue, Chadstone Vic 3148',
#   'code': 'unit-3-17-hillcrest-ave-chadstone-vic-3148',
#   'state': 'VIC',
#   'suburb': 'Chadstone',
#   'postcode': '3148'}]

# %%
# 由于 address code search 的 respond 都是 list, 即使是空的，或者多个的，用来check rate-limit
if isinstance(property_search_respond, dict):

    auproperty_api=os.getenv('auproperty_vincent2')

    auth_url = 'https://api2.aupropertyreport.com/api/auth'

    auth_response = requests.post(auth_url, data = {
                        'email':"leon20130301@hotmail.com",
                        'api_key':os.getenv('auproperty_vincent'),
                        })
    auth_token = auth_response.json() 
    access_token = auth_token['data']["token"]
    auth = {"Authorization":"Bearer " + access_token}
    print(auth) # 如果没有任何显示，则说明没有使用这个 API key

# %% [markdown]
# # Sate Auction Summary:

# %%
state_auction_summary_url = f"https://api2.aupropertyreport.com/api/state/{state}/auction-summary?date={date}"

# GET Request
state_auction_summary_request = requests.get(state_auction_summary_url,headers=auth,params={"limit":"50"})
state_auction_summary_respond = state_auction_summary_request.json()
state_auction_summary_respond
# Out:
# {'data': {'week': 12,
#   'state': 'VIC',
#   'auction_date': '2022-03-26',
#   'clearance_rate': 76.8,
#   'reported': 991,
#   'sold_before_auction': 266,
#   'sold_at_auction': 488,
#   'sold_after_auction': 7,
#   'withdrawn': 57,
#   'passed_in': 173,
#   'sold': 761,
#   'unsold': 230,
#   'sum_price': 658597227,
#   'median_price': 993000,
#   'updated_at': '2022-03-26'}}

# %% [markdown]
# # Sate Auction Result:

# %%
state_auction_result_url = f"https://api2.aupropertyreport.com/api/state/{state}/auction-results?date={date}"

# GET Request
state_auction_result_request = requests.get(state_auction_result_url,headers=auth,params={"limit":"50"})
state_auction_result_respond = state_auction_result_request.json()
state_auction_result_respond
# Out:
# {'data': {'week': 12,
#   'state': 'VIC',
#   'auction_date': '2022-03-26',
#   'clearance_rate': 76.8,
#   'reported': 991,
#   'sold_before_auction': 266,
#   'sold_at_auction': 488,
#   'sold_after_auction': 7,
#   'withdrawn': 57,
#   'passed_in': 173,
#   'sold': 761,
#   'unsold': 230,
#   'sum_price': 658597227,
#   'median_price': 993000,
#   'updated_at': '2022-03-26',
#   'results': {'data': [{'id': 431297934,
#      'address': '32 Little Turner St',
#      'state': 'VIC',
#      'suburb_name': 'Abbotsford',
#      'postcode': '3067',
#      'type': 'house',
#      'bed': 4,
#      'sold_date': '2022-03-26',
#      'price': 0,
#      'result': 'Passed In',
#      'is_sold': False,
#      'agency': 'Jellis Craig Fitzroy',
#      'pu_id': 19741649041},
#     {'id': 431997934,
#      'address': '9/11 Nicholson St',
#      'state': 'VIC',
#      'suburb_name': 'Abbotsford',
#      'postcode': '3067',
#      'type': 'townhouse',
#      'bed': 3,
#      'sold_date': '2022-03-26',
#      'price': 735000,
#      'result': 'Sold',
#      'is_sold': True,
#      'agency': 'Jellis Craig Richmond & Surrounds',
#      'pu_id': 39760814541},
#     {'id': 431608934,
#      'address': '10 St Phillips St',
#      'state': 'VIC',
#      'suburb_name': 'Abbotsford',
#      'postcode': '3067',
#      'type': 'house',
#      'bed': 3,
#      'sold_date': '2022-03-26',
#      'price': 1950000,
#      'result': 'Sold',
#      'is_sold': True,
#      'agency': 'Jellis Craig Richmond & Surrounds',
#      'pu_id': 39781823041},
#     {'id': 431318934,
#      'address': '402/36 Stafford St',
#      'state': 'VIC',
#      'suburb_name': 'Abbotsford',
#      'postcode': '3067',
#      'type': 'unit',
#      'bed': 3,
#      'sold_date': '2022-03-26',
#      'price': 852000,
#      'result': 'Sold',
#      'is_sold': True,
#      'agency': 'Nelson Alexander Fitzroy',
#      'pu_id': 39707987630},
#     {'id': 431028934,
#      'address': '6/1 Valiant St',
#      'state': 'VIC',
#      'suburb_name': 'Abbotsford',
#      'postcode': '3067',
#      'type': 'unit',
#      'bed': 2,
#      'sold_date': '2022-03-26',
#      'price': 0,
#      'result': 'Sold Prior',
#      'is_sold': True,
#      'agency': ' Jellis Craig & Company Pty Ltd',
#      'pu_id': 39726900141},
#     {'id': 431728934,
#      'address': '169 Vere St',
#      'state': 'VIC',
#      'suburb_name': 'Abbotsford',
#      'postcode': '3067',
#      'type': 'house',
#      'bed': 3,
#      'sold_date': '2022-03-26',
#      'price': 1535000,
#      'result': 'Sold',
#      'is_sold': True,
#      'agency': 'Nelson Alexander Fitzroy',
#      'pu_id': 39722661141},
#     {'id': 431438934,
#      'address': '202/56 Nicholson St',
#      'state': 'VIC',
#      'suburb_name': 'Abbotsford',
#      'postcode': '3067',
#      'type': 'townhouse',
#      'bed': 2,
#      'sold_date': '2022-03-26',
#      'price': 685000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'Biggin & Scott Richmond'},
#     {'id': 431148934,
#      'address': '3/10 Valiant St',
#      'state': 'VIC',
#      'suburb_name': 'Abbotsford',
#      'postcode': '3067',
#      'type': 'house',
#      'bed': 3,
#      'sold_date': '2022-03-26',
#      'price': 1340000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'Biggin & Scott Richmond'},
#     {'id': 431848934,
#      'address': '719A/609 Victoria St',
#      'state': 'VIC',
#      'suburb_name': 'Abbotsford',
#      'postcode': '3067',
#      'type': 'unit',
#      'bed': 2,
#      'sold_date': '2022-03-26',
#      'price': 645000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'Ray White Southbank & Port Phillip'},
#     {'id': 431558934,
#      'address': '34 Caroline St',
#      'state': 'VIC',
#      'suburb_name': 'Aberfeldie',
#      'postcode': '3040',
#      'type': 'house',
#      'bed': 4,
#      'sold_date': '2022-03-26',
#      'price': 2981000,
#      'result': 'Sold',
#      'is_sold': True,
#      'agency': 'Ray White Sunbury Pty Ltd',
#      'pu_id': 39709550641},
#     {'id': 431268934,
#      'address': '3 Beatrice Av',
#      'state': 'VIC',
#      'suburb_name': 'Aberfeldie',
#      'postcode': '3040',
#      'type': 'house',
#      'bed': 5,
#      'sold_date': '2022-03-26',
#      'price': 2540000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'Jellis Craig Essendon'},
#     {'id': 431968934,
#      'address': '6/2-4 Barton Ct',
#      'state': 'VIC',
#      'suburb_name': 'Aireys Inlet',
#      'postcode': '3231',
#      'type': 'house',
#      'bed': 2,
#      'sold_date': '2022-03-26',
#      'price': 860000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'Great Ocean Properties Aireys Inlet'},
#     {'id': 431678934,
#      'address': '13/16-20 Laurence Av',
#      'state': 'VIC',
#      'suburb_name': 'Airport West',
#      'postcode': '3042',
#      'type': 'villa',
#      'bed': 2,
#      'sold_date': '2022-03-26',
#      'price': 600000,
#      'result': 'Sold',
#      'is_sold': True,
#      'agency': 'Nelson Alexander Essendon',
#      'pu_id': 39766573141},
#     {'id': 431388934,
#      'address': '25 McNamara Av',
#      'state': 'VIC',
#      'suburb_name': 'Airport West',
#      'postcode': '3042',
#      'type': 'house',
#      'bed': 3,
#      'sold_date': '2022-03-26',
#      'price': 840000,
#      'result': 'Sold',
#      'is_sold': True,
#      'agency': 'Barry Plant Essendon',
#      'pu_id': 39745999841},
#     {'id': 431098934,
#      'address': '10 Oak St',
#      'state': 'VIC',
#      'suburb_name': 'Airport West',
#      'postcode': '3042',
#      'type': 'house',
#      'bed': 3,
#      'sold_date': '2022-03-26',
#      'price': 1207000,
#      'result': 'Sold Prior',
#      'is_sold': True,
#      'agency': 'Nelson Alexander Essendon',
#      'pu_id': 39783983141},
#     {'id': 431798934,
#      'address': '1/72-74 Parer Rd',
#      'state': 'VIC',
#      'suburb_name': 'Airport West',
#      'postcode': '3042',
#      'type': 'townhouse',
#      'bed': 2,
#      'sold_date': '2022-03-26',
#      'price': 650000,
#      'result': 'Sold',
#      'is_sold': True,
#      'agency': 'Barry Plant Essendon',
#      'pu_id': 39705202741},
#     {'id': 431409934,
#      'address': '1/2-4 Watt St',
#      'state': 'VIC',
#      'suburb_name': 'Airport West',
#      'postcode': '3042',
#      'type': 'unit',
#      'bed': 2,
#      'sold_date': '2022-03-26',
#      'price': 0,
#      'result': 'Sold Prior',
#      'is_sold': True,
#      'agency': 'NICOLE GERVASI PROPERTY GROUP',
#      'pu_id': 39768744441},
#     {'id': 431119934,
#      'address': '4/9 Kitson Cr',
#      'state': 'VIC',
#      'suburb_name': 'Airport West',
#      'postcode': '3042',
#      'type': 'unit',
#      'bed': 2,
#      'sold_date': '2022-03-26',
#      'price': 690000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'Nelson Alexander Essendon'},
#     {'id': 431819934,
#      'address': '29 McNamara Av',
#      'state': 'VIC',
#      'suburb_name': 'Airport West',
#      'postcode': '3042',
#      'type': 'house',
#      'bed': 3,
#      'sold_date': '2022-03-26',
#      'price': 850000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'Barry Plant Essendon'},
#     {'id': 431529934,
#      'address': '13a Varsity Ct',
#      'state': 'VIC',
#      'suburb_name': 'Albanvale',
#      'postcode': '3021',
#      'type': 'unit',
#      'bed': 2,
#      'sold_date': '2022-03-26',
#      'price': 497500,
#      'result': 'Sold',
#      'is_sold': True,
#      'agency': 'Ray White Taylors Lakes',
#      'pu_id': 39745237741},
#     {'id': 431239934,
#      'address': '8/140 Kerferd Rd',
#      'state': 'VIC',
#      'suburb_name': 'Albert Park',
#      'postcode': '3206',
#      'type': 'unit',
#      'bed': 2,
#      'sold_date': '2022-03-26',
#      'price': 810000,
#      'result': 'Sold',
#      'is_sold': True,
#      'agency': 'Marshall White',
#      'pu_id': 39707944251},
#     {'id': 431939934,
#      'address': '176 Kerferd Rd',
#      'state': 'VIC',
#      'suburb_name': 'Albert Park',
#      'postcode': '3206',
#      'type': 'house',
#      'bed': 4,
#      'sold_date': '2022-03-26',
#      'price': 0,
#      'result': 'Sold',
#      'is_sold': True,
#      'agency': 'Marshall White Port Phillip',
#      'pu_id': 39749503141},
#     {'id': 431649934,
#      'address': '70 Mills St',
#      'state': 'VIC',
#      'suburb_name': 'Albert Park',
#      'postcode': '3206',
#      'type': 'house',
#      'bed': 3,
#      'sold_date': '2022-03-26',
#      'price': 0,
#      'result': 'Passed In',
#      'is_sold': False,
#      'agency': 'Jellis Craig Port Phillip',
#      'pu_id': 19709080141},
#     {'id': 431359934,
#      'address': '16 St Vincent Pl N',
#      'state': 'VIC',
#      'suburb_name': 'Albert Park',
#      'postcode': '3206',
#      'type': 'house',
#      'bed': 3,
#      'sold_date': '2022-03-26',
#      'price': 0,
#      'result': 'Sold',
#      'is_sold': True,
#      'agency': 'Jellis Craig Port Phillip',
#      'pu_id': 39741922941},
#     {'id': 431069934,
#      'address': '8/28 Ridley St',
#      'state': 'VIC',
#      'suburb_name': 'Albion',
#      'postcode': '3020',
#      'type': 'unit',
#      'bed': 2,
#      'sold_date': '2022-03-26',
#      'price': 270000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'Create Vic Real Estate'},
#     {'id': 431769934,
#      'address': '94 Alfredton Dr',
#      'state': 'VIC',
#      'suburb_name': 'Alfredton',
#      'postcode': '3350',
#      'type': 'house',
#      'bed': 4,
#      'sold_date': '2022-03-26',
#      'price': 695000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'PRDnationwide Ballarat'},
#     {'id': 431479934,
#      'address': '6 Allura Dr',
#      'state': 'VIC',
#      'suburb_name': 'Alfredton',
#      'postcode': '3350',
#      'type': 'house',
#      'bed': 4,
#      'sold_date': '2022-03-26',
#      'price': 870000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'Trevor Petrie Real Estate'},
#     {'id': 431189934,
#      'address': '178 Cuthberts Rd',
#      'state': 'VIC',
#      'suburb_name': 'Alfredton',
#      'postcode': '3350',
#      'type': 'house',
#      'bed': 4,
#      'sold_date': '2022-03-26',
#      'price': 765000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'Buxton Ballarat'},
#     {'id': 431889934,
#      'address': '30 Cuthberts Rd',
#      'state': 'VIC',
#      'suburb_name': 'Alfredton',
#      'postcode': '3350',
#      'type': 'house',
#      'bed': 3,
#      'sold_date': '2022-03-26',
#      'price': 565000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'Jellis Craig Ballarat'},
#     {'id': 431599934,
#      'address': '75 Dorset Dr',
#      'state': 'VIC',
#      'suburb_name': 'Alfredton',
#      'postcode': '3350',
#      'type': 'house',
#      'bed': 4,
#      'sold_date': '2022-03-26',
#      'price': 840000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'McGrath Ballarat'},
#     {'id': 431201034,
#      'address': '25 Lugano Av',
#      'state': 'VIC',
#      'suburb_name': 'Alfredton',
#      'postcode': '3350',
#      'type': 'house',
#      'bed': 4,
#      'sold_date': '2022-03-26',
#      'price': 680000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'McGrath Ballarat'},
#     {'id': 431901034,
#      'address': '6 Parkwood St',
#      'state': 'VIC',
#      'suburb_name': 'Alfredton',
#      'postcode': '3350',
#      'type': 'house',
#      'bed': 3,
#      'sold_date': '2022-03-26',
#      'price': 630000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'Trevor Petrie Real Estate'},
#     {'id': 431611034,
#      'address': '10 Perendale St',
#      'state': 'VIC',
#      'suburb_name': 'Alfredton',
#      'postcode': '3350',
#      'type': 'house',
#      'bed': 3,
#      'sold_date': '2022-03-26',
#      'price': 600000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'PRDnationwide Ballarat'},
#     {'id': 431321034,
#      'address': '2 Shannon Cl',
#      'state': 'VIC',
#      'suburb_name': 'Alfredton',
#      'postcode': '3350',
#      'type': 'house',
#      'bed': 2,
#      'sold_date': '2022-03-26',
#      'price': 380000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'Buxton Ballarat'},
#     {'id': 431031034,
#      'address': '6 Waterway Dr',
#      'state': 'VIC',
#      'suburb_name': 'Alfredton',
#      'postcode': '3350',
#      'type': 'house',
#      'bed': 4,
#      'sold_date': '2022-03-26',
#      'price': 1555000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'Buxton Ballarat'},
#     {'id': 431731034,
#      'address': '77 Bracken Gr',
#      'state': 'VIC',
#      'suburb_name': 'Altona',
#      'postcode': '3018',
#      'type': 'house',
#      'bed': 5,
#      'sold_date': '2022-03-26',
#      'price': 1700000,
#      'result': 'Sold',
#      'is_sold': True,
#      'agency': 'Barlow McEwan Tribe Altona',
#      'pu_id': 39728174541},
#     {'id': 431441034,
#      'address': '5/126 Blyth St',
#      'state': 'VIC',
#      'suburb_name': 'Altona',
#      'postcode': '3018',
#      'type': 'unit',
#      'bed': 2,
#      'sold_date': '2022-03-26',
#      'price': 517000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'hockingstuart Altona & Hobsons Bay'},
#     {'id': 431151034,
#      'address': '1 Finch St',
#      'state': 'VIC',
#      'suburb_name': 'Altona',
#      'postcode': '3018',
#      'type': 'house',
#      'bed': 2,
#      'sold_date': '2022-03-26',
#      'price': 1605000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'Sweeney Altona, Altona Meadows & Altona North'},
#     {'id': 431851034,
#      'address': '205/113 Pier St',
#      'state': 'VIC',
#      'suburb_name': 'Altona',
#      'postcode': '3018',
#      'type': 'unit',
#      'bed': 2,
#      'sold_date': '2022-03-26',
#      'price': 449900,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'Mancini Real Estate '},
#     {'id': 431561034,
#      'address': '10/70 Queen St',
#      'state': 'VIC',
#      'suburb_name': 'Altona',
#      'postcode': '3018',
#      'type': 'unit',
#      'bed': 2,
#      'sold_date': '2022-03-26',
#      'price': 502000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'Barlow McEwan Tribe Altona'},
#     {'id': 431271034,
#      'address': '51 Nicholson St',
#      'state': 'VIC',
#      'suburb_name': 'Altona Meadows',
#      'postcode': '3028',
#      'type': 'house',
#      'bed': 3,
#      'sold_date': '2022-03-26',
#      'price': 727000,
#      'result': 'Sold Prior',
#      'is_sold': True,
#      'agency': 'hockingstuart Altona & Hobsons Bay',
#      'pu_id': 39722858541},
#     {'id': 431971034,
#      'address': '68 Nicholson St',
#      'state': 'VIC',
#      'suburb_name': 'Altona Meadows',
#      'postcode': '3028',
#      'type': 'house',
#      'bed': 4,
#      'sold_date': '2022-03-26',
#      'price': 1360000,
#      'result': 'Sold Prior',
#      'is_sold': True,
#      'agency': 'hockingstuart Altona & Hobsons Bay',
#      'pu_id': 39720277741},
#     {'id': 431681034,
#      'address': '270 Merton St',
#      'state': 'VIC',
#      'suburb_name': 'Altona Meadows',
#      'postcode': '3028',
#      'type': 'house',
#      'bed': 4,
#      'sold_date': '2022-03-26',
#      'price': 860000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'Waterfront Real Estate'},
#     {'id': 431391034,
#      'address': '21 Orville St',
#      'state': 'VIC',
#      'suburb_name': 'Altona Meadows',
#      'postcode': '3028',
#      'type': 'house',
#      'bed': 4,
#      'sold_date': '2022-03-26',
#      'price': 760000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'Compton Green'},
#     {'id': 431002034,
#      'address': '123/390 Queen St',
#      'state': 'VIC',
#      'suburb_name': 'Altona Meadows',
#      'postcode': '3028',
#      'type': 'unit',
#      'bed': 2,
#      'sold_date': '2022-03-26',
#      'price': 425000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'Waterfront Real Estate'},
#     {'id': 431702034,
#      'address': '20 Rebecca Cr',
#      'state': 'VIC',
#      'suburb_name': 'Altona Meadows',
#      'postcode': '3028',
#      'type': 'house',
#      'bed': 3,
#      'sold_date': '2022-03-26',
#      'price': 738000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'Sweeney Altona, Altona Meadows & Altona North'},
#     {'id': 431412034,
#      'address': '124 Victoria St',
#      'state': 'VIC',
#      'suburb_name': 'Altona Meadows',
#      'postcode': '3028',
#      'type': 'house',
#      'bed': 4,
#      'sold_date': '2022-03-26',
#      'price': 809500,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'Barlow McEwan Tribe Altona'},
#     {'id': 431122034,
#      'address': '220 Victoria St',
#      'state': 'VIC',
#      'suburb_name': 'Altona Meadows',
#      'postcode': '3028',
#      'type': 'house',
#      'bed': 4,
#      'sold_date': '2022-03-26',
#      'price': 880000,
#      'result': 'Private Sale',
#      'is_sold': True,
#      'agency': 'Mancini Real Estate '},
#     {'id': 431822034,
#      'address': '2 Lee St',
#      'state': 'VIC',
#      'suburb_name': 'Altona North',
#      'postcode': '3025',
#      'type': 'house',
#      'bed': 3,
#      'sold_date': '2022-03-26',
#      'price': 631000,
#      'result': 'Sold',
#      'is_sold': True,
#      'agency': 'Sweeney Altona, Altona Meadows & Altona North',
#      'pu_id': 39726352841},
#     {'id': 431532034,
#      'address': '37 Macdonald Av',
#      'state': 'VIC',
#      'suburb_name': 'Altona North',
#      'postcode': '3025',
#      'type': 'house',
#      'bed': 4,
#      'sold_date': '2022-03-26',
#      'price': 1196000,
#      'result': 'Sold',
#      'is_sold': True,
#      'agency': 'LJ Hooker Altona North',
#      'pu_id': 39760692130}],
#    'meta': {'pagination': {'total': 2465,
#      'count': 50,
#      'per_page': 50,
#      'current_page': 1,
#      'total_pages': 50,
#      'links': {'next': 'https://api2.aupropertyreport.com/api/state/vic/auction-results?date=2022-03-26&limit=50&page=2'}}}}}}

# %% [markdown]
# # Sate for Sale Properties: 注意有 800 pages+

# %%
state_for_sale_url = f"https://api2.aupropertyreport.com/api/state/{state}/buy"

# GET Request
state_for_sale_request = requests.get(state_for_sale_url,headers=auth,params={"limit":"50"})
state_for_sale_respond = state_for_sale_request.json()
state_for_sale_respond
# Out:
# {'data': {'state_code': 'VIC',
#   'buy': {'data': [{'state': 'VIC',
#      'address': '3 Kalmia Court',
#      'suburb_code': 'narre-warren-vic-3805',
#      'suburb_name': 'Narre Warren',
#      'postcode': '3805',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQU01sWldkbE9mU3YxK0JMV29mZ0FsUmMrMC9zeUJUWTNBRjZPWUJGdENhZGVZckNsRXplS1pqOTNCbTlxdTJuMVdrbmw2OVhhdDhJWmJyVUozQ0h0RlJmTGNEZVV6TmN2VW05SWlRNUxjWXFBPT0/preview.jpg',
#      'type': 'house',
#      'bed': 5,
#      'bath': 3,
#      'car': 4,
#      'lat': -38.013934,
#      'lng': 145.313765,
#      'land': '',
#      'list_date': '2022-03-29',
#      'list_price': '',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19741166861,
#      'agent_code': 'VIC353817'},
#     {'state': 'VIC',
#      'address': '128 Milton Parade',
#      'suburb_code': 'glen-iris-vic-3146',
#      'suburb_name': 'Glen Iris',
#      'postcode': '3146',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQVGVHSENSV1QweFc4VGdydHlBTURKTUJnVXdheTRTK0Z2TlJLWjl6U0JuallJaWE3STVGR1RDazRVVVlxL1I5b1JFdjR0K1lBWFNaZ3FvZVdtY0lESThqMlQxODNtbUhUbmFMNnJ3b0o4S1ZRPT0/preview.jpg',
#      'type': 'townhouse',
#      'bed': 3,
#      'bath': 2,
#      'car': 2,
#      'lat': -37.851353,
#      'lng': 145.044884,
#      'land': '',
#      'list_date': '2022-03-29',
#      'list_price': '',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19707166861,
#      'agent_code': 'VIC352787'},
#     {'state': 'VIC',
#      'address': 'Lot 40220, Dockrillia Boulevard',
#      'suburb_code': 'mickleham-vic-3064',
#      'suburb_name': 'Mickleham',
#      'postcode': '3064',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQU2ovMHZFRjZJaC9wd0tEY1kvTDN1cm9LU0swQnhkanZ6N29EQ0M5WVhxZklZdzI1VWJuLzRHRm1nT2ZDazZZK1U3SHo2bk84bnRBZGV1R2RQUjhFK1BORFJmVVdKaEFsVXVRS0Vmc0gvZFdBPT0/preview.jpg',
#      'type': 'residential land',
#      'bed': 0,
#      'bath': 0,
#      'car': 0,
#      'lat': 0,
#      'lng': 0,
#      'land': '572',
#      'list_date': '2022-03-29',
#      'list_price': '$539,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 14826792266,
#      'agent_code': 'VIC80610'},
#     {'state': 'VIC',
#      'address': '5/670 Somerton Road',
#      'suburb_code': 'greenvale-vic-3059',
#      'suburb_name': 'Greenvale',
#      'postcode': '3059',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQU2U0SjZ5ckRzTjZQZmFzYUQ2c0NOWUZCODZUZzJWVnZmcmdoQldUZndLQmZmWFlPU0JlNkdZQ3R3YVRkV09KYnJxaUV3aTFYYnVYQytLTGRKWlFIbXFwZk5RNys3VXlhNUgzZFc1RWJCQzlRPT0/preview.jpg',
#      'type': 'townhouse',
#      'bed': 3,
#      'bath': 2,
#      'car': 2,
#      'lat': -37.635665,
#      'lng': 144.888888,
#      'land': '',
#      'list_date': '2022-03-29',
#      'list_price': '$570,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19745266861,
#      'agent_code': 'VIC339014'},
#     {'state': 'VIC',
#      'address': 'Lot 40223, Dockrillia Boulevard',
#      'suburb_code': 'mickleham-vic-3064',
#      'suburb_name': 'Mickleham',
#      'postcode': '3064',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQVDFUNzdUT0NSYWRrdEdJNXpqY3RnSlNsL0dPcC9wSGVKU2JSK0V1ZWhNZk9EUnRzY0R5L01YbzB0UHNvS0IyemEzOG1XbHhEbXgzMHlKWkZJbi83elc3S09iU3pPYVQ1UjNPN1JRR1phZzFBPT0/preview.jpg',
#      'type': 'residential land',
#      'bed': 0,
#      'bath': 0,
#      'car': 0,
#      'lat': 0,
#      'lng': 0,
#      'land': '434',
#      'list_date': '2022-03-29',
#      'list_price': '$458,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 14809792266,
#      'agent_code': 'VIC80610'},
#     {'state': 'VIC',
#      'address': '66 Gresham Way',
#      'suburb_code': 'sunshine-west-vic-3020',
#      'suburb_name': 'Sunshine West',
#      'postcode': '3020',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUk1wSjZVZE5OY2czU0paR0c5Qmw4a2hQcXFUSTdmeGxIaEQ3eU9SR1JhMDhHcFR0ckRaQzgwY09YZjdMM2NXWDlCdWZHUXltdGc2cDFJWkJRTHRyT3AwWkZ4UTZnWXZDZXl6M3dpcU1ILzlnPT0/preview.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 1,
#      'car': 1,
#      'lat': -37.800122,
#      'lng': 144.804939,
#      'land': '',
#      'list_date': '2022-03-29',
#      'list_price': '$550,000 - $600,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19705466861,
#      'agent_code': 'VIC3990'},
#     {'state': 'VIC',
#      'address': '1/5 Garnet Court',
#      'suburb_code': 'hampton-park-vic-3976',
#      'suburb_name': 'Hampton Park',
#      'postcode': '3976',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQVDRTc0JKN1NpdmRGS3UxU1NCQ01oVVoyTEZRS2twd1phKzVKdHU1TFBBUkF4aFkyeTN1N1IyZ2loamwybWM5M1BieFFRN25OYldQcmg3bmdVQlNiR29YMWJDRnI4ZXY4LzhxTENiTFI1YzhRPT0/preview.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 1,
#      'car': 2,
#      'lat': -38.0277581,
#      'lng': 145.247899,
#      'land': '',
#      'list_date': '2022-03-29',
#      'list_price': '$550,000 - $600,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19707866861,
#      'agent_code': 'VIC5237'},
#     {'state': 'VIC',
#      'address': '10 Winona Road',
#      'suburb_code': 'mount-eliza-vic-3930',
#      'suburb_name': 'Mount Eliza',
#      'postcode': '3930',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQVFFvOTF1SzlkWkxHc1Q3ODhMdlhBQ0drTWpUUFpZUEg4ekszRlNZUVN2a3h5UEQ5NzhEM0RBOXh3ME1LSGJEeVM5RDR4a3k3MjJPZGFyQmRSMzIvUWxLZDR1c0ExQWdGRmpqenY2R2RCaHJnPT0/preview.jpg',
#      'type': 'house',
#      'bed': 7,
#      'bath': 4,
#      'car': 1,
#      'lat': -38.202715,
#      'lng': 145.106368,
#      'land': '3827',
#      'list_date': '2022-03-29',
#      'list_price': '$2,300,000 - $2,500,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19789866861,
#      'agent_code': 'VIC197810'},
#     {'state': 'VIC',
#      'address': 'Lot 40236, Chorilaena Way',
#      'suburb_code': 'mickleham-vic-3064',
#      'suburb_name': 'Mickleham',
#      'postcode': '3064',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQVDBuWXpqVDY3anhqR3JPd2lsT2d3ajZERzNhenBNbEU5cXovbkN4QVdWcDMyd1FudVVmb3ZQaUpudXJDMDdtYmdxeDBBaFB5alFKUkdxeW0rNkV2VDI3NDdlL1FXbklWbzR1RjNvMjNzT0xBPT0/preview.jpg',
#      'type': 'residential land',
#      'bed': 0,
#      'bath': 0,
#      'car': 0,
#      'lat': 0,
#      'lng': 0,
#      'land': '382',
#      'list_date': '2022-03-29',
#      'list_price': '$411,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 14803992266,
#      'agent_code': 'VIC80610'},
#     {'state': 'VIC',
#      'address': '68 First Avenue',
#      'suburb_code': 'rosebud-vic-3939',
#      'suburb_name': 'Rosebud',
#      'postcode': '3939',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQVG0yYkRQemdZYlJKd2MyeEtaYkllTW5zNlVZSW05cXZiM3VlSnBWaXREVVJEN0l3amV0WmF4Q1N6cytoN0NLRHpGK0RxcEhweHZpRDczREZ1cndBMXdRVitYdFRkeUJvaXp3TGJCaFlSV1hnPT0/preview.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 1,
#      'car': 3,
#      'lat': -38.3649,
#      'lng': 144.895562,
#      'land': '805',
#      'list_date': '2022-03-29',
#      'list_price': '$995,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19722176861,
#      'agent_code': 'VIC247487'},
#     {'state': 'VIC',
#      'address': 'Lot 40256, Doryanthes Way',
#      'suburb_code': 'mickleham-vic-3064',
#      'suburb_name': 'Mickleham',
#      'postcode': '3064',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQVGk3am5qaFlDdVUyRTllaVgvZkhVaGx2VjlqWUJDK1lpQVg2ZDNNL3lwcmNuRnU3R3FEWSs5MUV6cER0SVQyY3kzTExsY1FpaXI5S2dIZmkzaWR6VTRJeGdtMjFlZ1h6aXF0TUU5RXNYMkdRPT0/preview.jpg',
#      'type': 'residential land',
#      'bed': 0,
#      'bath': 0,
#      'car': 0,
#      'lat': 0,
#      'lng': 0,
#      'land': '213',
#      'list_date': '2022-03-29',
#      'list_price': '$282,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 14885992266,
#      'agent_code': 'VIC80610'},
#     {'state': 'VIC',
#      'address': '46 Scenic Road',
#      'suburb_code': 'cape-paterson-vic-3995',
#      'suburb_name': 'Cape Paterson',
#      'postcode': '3995',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQVDZhVjNSREJPcVB6bm9IMkcrTWt0dUNaQWtKR21xNktmQkdsRCtMMFA0amMvQXhjQm9vRlU2NW4xcVpzNUw3UVQrRVkxOWZFOWdGTVBIMGVvNTk1YXhXMmY2TGg5NzhQbU5OcjFGak56b0FBPT0/preview.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 2,
#      'car': 2,
#      'lat': -38.6688581,
#      'lng': 145.6090456,
#      'land': '',
#      'list_date': '2022-03-29',
#      'list_price': '',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19726276861,
#      'agent_code': 'VIC199852'},
#     {'state': 'VIC',
#      'address': '615/65 Coventry Street',
#      'suburb_code': 'southbank-vic-3006',
#      'suburb_name': 'Southbank',
#      'postcode': '3006',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQVEQxUU5NR1o1Nm44TDRwUlU5ay9VYlVSOU9mSkw5YXNrcXBwMFNRVk5ER0xsRW9tVjVWTVZuRERLNU84NXZQNHIwcldTUFNlZk9RYUIvRE1lZy9jZktJR3V5VGdGenRHNTR0b1dCYTNyNTR3PT0/preview.jpg',
#      'type': 'apartment',
#      'bed': 1,
#      'bath': 1,
#      'car': 0,
#      'lat': -37.8298566,
#      'lng': 144.9678508,
#      'land': '',
#      'list_date': '2022-03-29',
#      'list_price': '$285,000 - $300,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19781376861,
#      'agent_code': 'VIC170011'},
#     {'state': 'VIC',
#      'address': 'Address available on request',
#      'suburb_code': 'deanside-vic-3336',
#      'suburb_name': 'Deanside',
#      'postcode': '3336',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQVFp0d2orTXorTnU4QjE1NVZJeW5UWkYzTENuRHBqNVlkblloSlFYZ3hibk16Q1VrRktQdmp4NTVRT3pBS1QrdGtVTksyUjBpT3hLMUJYZklybVdjK1dpZ25vQjY5UmwxL01DTWFpT05CYUlRPT0/preview.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 2,
#      'car': 2,
#      'lat': 0,
#      'lng': 0,
#      'land': '313',
#      'list_date': '2022-03-29',
#      'list_price': '$593,900',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19785476861,
#      'agent_code': 'VIC326748'},
#     {'state': 'VIC',
#      'address': '4 Rockgarden Way',
#      'suburb_code': 'wollert-vic-3750',
#      'suburb_name': 'Wollert',
#      'postcode': '3750',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUWtROUZ2Njg2cTFoNGVwbXdUbS9BeHRBc0pkZ3VkNkIrWEM2M3dUQWIzcWZZNE82RFVwYWJBRmZ5Mk5TdjNHNERiMktVcS8rbGljUG8zOGNDeCsxTUxQWHMrWlloY09sM0pjV2pvWnloeVFnPT0/preview.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 2,
#      'car': 2,
#      'lat': -37.6102061,
#      'lng': 145.0425795,
#      'land': '512',
#      'list_date': '2022-03-29',
#      'list_price': '$950,000 - $990,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19762676861,
#      'agent_code': 'VIC340556'},
#     {'state': 'VIC',
#      'address': '295 Tynong North Road',
#      'suburb_code': 'tynong-north-vic-3813',
#      'suburb_name': 'Tynong North',
#      'postcode': '3813',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQU0Z5NXp2Yk5JYllxVTVhbHdaVFEwWXlScDVhNEVzQjhGWW40VEZBYWdTM3FRc3hpcFJvdXJvdzVjL0NMV1d3TmdVTFRHVDFTMTJLSnhVMVJ5cTBUQ3dmSUdUL2ExdWxSYmgwZnRSUE95ZXNRPT0/preview.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 2,
#      'car': 10,
#      'lat': -38.0471949,
#      'lng': 145.6318233,
#      'land': '82500',
#      'list_date': '2022-03-29',
#      'list_price': '$1,550,000 - $1,650,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19722876861,
#      'agent_code': 'VIC180894'},
#     {'state': 'VIC',
#      'address': '29 Fullarton Drive',
#      'suburb_code': 'paynesville-vic-3880',
#      'suburb_name': 'Paynesville',
#      'postcode': '3880',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQU0N3TjFYMzR4STV4QXVKWmw4U3F3NmdnT0xTMGtqSFBlQS9pdmJnZmtNYkhYaW5iTXZ3OWZYWDJiRC9aN3NuMW55SjE0L1RsREhqM0t2MGtPdmVkV01sQ21CUEphTTB0WGNMclZWUnZqaXlRPT0/preview.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 2,
#      'car': 4,
#      'lat': -37.904689,
#      'lng': 147.7159173,
#      'land': '800',
#      'list_date': '2022-03-29',
#      'list_price': '$829,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19743976861,
#      'agent_code': 'VIC155613'},
#     {'state': 'VIC',
#      'address': '33 Denbigh Court',
#      'suburb_code': 'keilor-vic-3036',
#      'suburb_name': 'Keilor',
#      'postcode': '3036',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQU24xaVBId0FGRWFUWDhHWDR0QS9QbWsrbXRHdGM3bXdGRXJJcjUzQlJ4Ynd1VVZhOS85WCtMcUtGa2p4aGd6ditXU0Z2cTJLVm1mWk1WTG0wKzRXZi9Ga0xlSFI0dmZIdDBLYVljMjFERWp3PT0/preview.png',
#      'type': 'residential land',
#      'bed': 0,
#      'bath': 0,
#      'car': 0,
#      'lat': -37.7137834,
#      'lng': 144.8130446,
#      'land': '785',
#      'list_date': '2022-03-29',
#      'list_price': '',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 14841003266,
#      'agent_code': 'VIC3890'},
#     {'state': 'VIC',
#      'address': '82 Cave Hill Road',
#      'suburb_code': 'lilydale-vic-3140',
#      'suburb_name': 'Lilydale',
#      'postcode': '3140',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUTFsYkhyVnAyckhlMElDS3huQUJ5bVEvd1RvUnNDMzR3VEUxTzZ2Z0N1MnNLY3cvaUFXcjFWZFE0ZHpzVjZRemxDa0NSUkxuTFhtUFJCZC9UK1dnK1NhL1NnTVIvcitDbFlWbkFERFVNZGhnPT0/preview.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 1,
#      'car': 2,
#      'lat': -37.749264,
#      'lng': 145.344727,
#      'land': '878',
#      'list_date': '2022-03-29',
#      'list_price': '$790,000 - $850,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19768186861,
#      'agent_code': 'VIC223355'},
#     {'state': 'VIC',
#      'address': '901/89-103 Gladstone Street',
#      'suburb_code': 'south-melbourne-vic-3205',
#      'suburb_name': 'South Melbourne',
#      'postcode': '3205',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUkQxcDZObnF0MXFwV0pkQlNrZTM0N1RwTlBOOG1aam5kU3NUQjQxWW9VWUoyY2hMMUFnN0ZMME1TZ3FzaE9RampNeGFISlVzYW0ySTJkUXQ5djBEK3FURmRjZElSNHpVcjdnTjUvdGhSY21RPT0/preview.jpg',
#      'type': 'apartment',
#      'bed': 2,
#      'bath': 1,
#      'car': 0,
#      'lat': -37.8301487,
#      'lng': 144.9500924,
#      'land': '',
#      'list_date': '2022-03-29',
#      'list_price': '',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19762386861,
#      'agent_code': 'VIC313743'},
#     {'state': 'VIC',
#      'address': '33 Gould Street',
#      'suburb_code': 'frankston-vic-3199',
#      'suburb_name': 'Frankston',
#      'postcode': '3199',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUitxVVhLeTFhY01uNXhXWnZQcVFFZmFqbHZkemNZT1Y5NmkvQjZ0QU1TRFBGc2FUQnZGYm8vYW43UzVSU2xyYmdxak9veU9CbmpvZEptL1hHSmlZREdhY1MzUVMyYUNnZHBERkJKb3VWZm1nPT0/preview.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 2,
#      'car': 2,
#      'lat': -38.132099,
#      'lng': 145.123129,
#      'land': '590',
#      'list_date': '2022-03-29',
#      'list_price': '',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19764786861,
#      'agent_code': 'VIC7921'},
#     {'state': 'VIC',
#      'address': '84/100 Keilor Road',
#      'suburb_code': 'essendon-north-vic-3041',
#      'suburb_name': 'Essendon North',
#      'postcode': '3041',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQU1dIN1FaQkI1dms1MEhMcWRnMFBoQVRsTTlZV2JEU3d6Z1QvRlpCeFB1bGlFV1FjeXVNM3lTeFpjU2ZVV01Ga2R2Y2lhOWV2ODNNMEkrOFdqeGxSL3ZOWGtINEZ1TVNGRzdaMEk0VXVoMFNRPT0/preview.jpg',
#      'type': 'apartment',
#      'bed': 2,
#      'bath': 2,
#      'car': 1,
#      'lat': -37.742013,
#      'lng': 144.9043832,
#      'land': '',
#      'list_date': '2022-03-29',
#      'list_price': '$390,000 - $420,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19720886861,
#      'agent_code': 'VIC4542'},
#     {'state': 'VIC',
#      'address': '18 Kheminda Crescent',
#      'suburb_code': 'nagambie-vic-3608',
#      'suburb_name': 'Nagambie',
#      'postcode': '3608',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQVGoyVTVGUzRGaXl3ZlRwQVB0dU40ejVRcE5qNFZ4WnF3T3JGZExLRk1ib3RMb2RYS0JXUmVuT3kyamZrOGc0c1g4M1dqSG5vY1dwSDR0WEhyVjJ5OGNGWDNrejI5S1dpTzRJRGtoZGNlaTFBPT0/preview.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 2,
#      'car': 8,
#      'lat': -36.7802134,
#      'lng': 145.1593812,
#      'land': '834',
#      'list_date': '2022-03-29',
#      'list_price': '$1,200,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19741986861,
#      'agent_code': 'VIC114679'},
#     {'state': 'VIC',
#      'address': '20A McGowan Street',
#      'suburb_code': 'long-gully-vic-3550',
#      'suburb_name': 'Long Gully',
#      'postcode': '3550',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUVVPZk1XbnA4MytQZU9GVkl4RVAzZjd0eXA4NFZyR3VMa1E4MlV2bEQ0WEQxSm9SZGUvaTByZk9QUlZGczJzMStzR1hBaE80TmJWWk95MTF5UGlXT1N0RHpOZkdJN1kxUGdnL21lcjVvZm9RPT0/preview.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 1,
#      'car': 1,
#      'lat': -36.7351161,
#      'lng': 144.2626904,
#      'land': '401',
#      'list_date': '2022-03-29',
#      'list_price': '$369,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19762096861,
#      'agent_code': 'VIC226747'},
#     {'state': 'VIC',
#      'address': '65 Edward Street',
#      'suburb_code': 'langwarrin-vic-3910',
#      'suburb_name': 'Langwarrin',
#      'postcode': '3910',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQU2ZpUjhkQnBnbWtyNmR5ci84SldnMlFRSEY1T21vUFdUOFUvSithMVZUL2l5ZVJEemNXR3o5cXc1cWpJTW1hZmhsNWpVR040M2pxd1BiK1lqT3BVSHNaRnRpS09XemRoU0s5SmlnOHhGQ3hRPT0/preview.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 2,
#      'car': 4,
#      'lat': -38.153758,
#      'lng': 145.178905,
#      'land': '',
#      'list_date': '2022-03-29',
#      'list_price': '$900,000 - $990,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19707696861,
#      'agent_code': 'VIC130285'},
#     {'state': 'VIC',
#      'address': '73 Williamstown Road',
#      'suburb_code': 'seddon-vic-3011',
#      'suburb_name': 'Seddon',
#      'postcode': '3011',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQU1FqRzRiK1Q1ZG43cWQyanFNTnZkd0lETWNyT1d0NWVqa242NUs2L0RCVlRNK3lXaHpDUWJvK21GQ1lsb3pWZUVSc2JaTTh6cWFaS3FMelZEVE9tRy9NSFBrZ0dSQmczS1ZGRjdMNTR3djJ3PT0/preview.jpg',
#      'type': 'house',
#      'bed': 2,
#      'bath': 1,
#      'car': 0,
#      'lat': -37.806699,
#      'lng': 144.884831,
#      'land': '220',
#      'list_date': '2022-03-29',
#      'list_price': '$800,000 - $880,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19789696861,
#      'agent_code': 'VIC262899'},
#     {'state': 'VIC',
#      'address': '5 Burdekin Street',
#      'suburb_code': 'manor-lakes-vic-3024',
#      'suburb_name': 'Manor Lakes',
#      'postcode': '3024',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUVVFaHkvcEN5Yjc3bXNzaEg5ZVh6NFV0ekN4aFRrTWxZTHVlNEJnaGtoQ2w1cDZvQVZ5NzZoOUovRjY3c3NINmJKR290UjBadGpMTmQ5U3M2eHQrdnNiT1ZyN1V0RzRoSVNQOVUwbVUxMVRRPT0/preview.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 2,
#      'car': 4,
#      'lat': -37.8786638,
#      'lng': 144.6064834,
#      'land': '512',
#      'list_date': '2022-03-29',
#      'list_price': '$630,000 - $650,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19762796861,
#      'agent_code': 'VIC280473'},
#     {'state': 'VIC',
#      'address': '45 High Street',
#      'suburb_code': 'altona-meadows-vic-3028',
#      'suburb_name': 'Altona Meadows',
#      'postcode': '3028',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUkRQMFRYWHBuV3ArQ2JYMERlUnNyUXBuSldRYnBiTi9lRytOTXkzRkVuZFFEN0JXc2tDa2E4RGZKbnBmTHBidzk0cHBGenN6aEo3L2lQbWpXK01iUEpaOXl0b1BTbVNreWxnR0RxV1FSbDRRPT0/preview.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 2,
#      'car': 4,
#      'lat': -37.8688539,
#      'lng': 144.7735507,
#      'land': '462',
#      'list_date': '2022-03-29',
#      'list_price': '$780,000 - $799,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19745796861,
#      'agent_code': 'VIC264438'},
#     {'state': 'VIC',
#      'address': '10-16 Lilydale Grove',
#      'suburb_code': 'hawthorn-east-vic-3123',
#      'suburb_name': 'Hawthorn East',
#      'postcode': '3123',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQVGYzQkJ3UjRiMGRSQmw0RzRZK0JER2hoQlpGRW82ZFg5b3hIQjNCT080Tk04b0Z0MmtMUFJYWGdGL2J5WE95ZG9vZlpXbnU5RXhaeFV6TFZQTGxWdHZjbHB2V04vaVNIeDZKbTdEQStnTm1nPT0/preview.jpg',
#      'type': 'apartment',
#      'bed': 3,
#      'bath': 3,
#      'car': 2,
#      'lat': -37.8229683,
#      'lng': 145.0469853,
#      'land': '',
#      'list_date': '2022-03-29',
#      'list_price': '$2,200,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19749896861,
#      'agent_code': 'VIC352787'},
#     {'state': 'VIC',
#      'address': 'Lot 36305, Highlander drive',
#      'suburb_code': 'craigieburn-vic-3064',
#      'suburb_name': 'Craigieburn',
#      'postcode': '3064',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUnBwd081M0FsYWJ3cTVycE1aMU9OQTNCSGczRUtXU3BreFdrRHUva3p0MUxrVStSdFB0OG5VZ0d1c2E1K21zYXo3cGJkS1diYkwwSktacDlKcG81QUJHY21aOGRBSG1kWmMxa2RoM2lJZ3J3PT0/preview.jpg',
#      'type': 'residential land',
#      'bed': 0,
#      'bath': 0,
#      'car': 0,
#      'lat': -37.5779562,
#      'lng': 144.8964815,
#      'land': '457',
#      'list_date': '2022-03-29',
#      'list_price': '',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 14801203266,
#      'agent_code': 'VIC298961'},
#     {'state': 'VIC',
#      'address': 'lot 414 Epping Dr',
#      'suburb_code': 'wyndham-vale-vic-3024',
#      'suburb_name': 'Wyndham Vale',
#      'postcode': '3024',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQVFRDZXVCZXYzdTVPZTh6WTF6VjNZVnVmbFdWejB2TEMzZFRsUGh0dzZ4aWVOQzhoMnJCR29rMDVJOFprUy9KM2FxVjRacm5MdFhmeVhreFEwSDJiWmJtY0s1dUhYejAyNlcrbktsUTNvWnFRPT0/preview.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 2,
#      'car': 1,
#      'lat': -37.8687217,
#      'lng': 144.6283203,
#      'land': '212',
#      'list_date': '2022-03-29',
#      'list_price': '$453,700',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19726007861,
#      'agent_code': 'VIC170509'},
#     {'state': 'VIC',
#      'address': '631 Plenty Road',
#      'suburb_code': 'preston-vic-3072',
#      'suburb_name': 'Preston',
#      'postcode': '3072',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUXNFQXdQK0NPaXVzK3B5d2lxNGEwaE9abDg0cXpzeHRjNFk2bGNiNlBpU3hHL0xvUjB2N0Z3Zjc5bWNGUVN0UG04OHNCVldnTldUY29Bb3RUU3M2bWoyeDkrYTZMeXFKc3JUQzVpR04xK0hBPT0/preview.jpg',
#      'type': 'apartment',
#      'bed': 1,
#      'bath': 1,
#      'car': 1,
#      'lat': -37.731522,
#      'lng': 145.0141819,
#      'land': '',
#      'list_date': '2022-03-29',
#      'list_price': '$399,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19703207861,
#      'agent_code': 'VIC352787'},
#     {'state': 'VIC',
#      'address': '1492 High Street',
#      'suburb_code': 'glen-iris-vic-3146',
#      'suburb_name': 'Glen Iris',
#      'postcode': '3146',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQU2dDZSt3Z0VuYUJHV0kxOTNIa2d4Z2ducVczSXY1Wko2bDRraVVhV0E3S3FqekhMUTZNNEoxUE16bFFEMHQ2U1lhR3BzU3V3YVFiYUYra2J0Wk9zRElOeW5hQWJYbkJiR0s0OExFNUNhSDJBPT0/preview.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 1,
#      'car': 4,
#      'lat': -37.858782,
#      'lng': 145.045108,
#      'land': '364',
#      'list_date': '2022-03-29',
#      'list_price': '$1,350,000 -1,400,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19762407861,
#      'agent_code': 'VIC290376'},
#     {'state': 'VIC',
#      'address': '32 Stuart Street',
#      'suburb_code': 'the-basin-vic-3154',
#      'suburb_name': 'The Basin',
#      'postcode': '3154',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUmtsdXJNc0Zjb3dFeUs2Z1g4VWUwOGREQ3VjdE9zd3JucVNkN0tQbUV0VVMvSDBlcVpOWmxZZ3VJZHcwZDVUNDRUOGp3dnpFZ3AwL0pnS0xucjl0QW54WVVhVzRpR2lMOTZXYUZuSngwTFVRPT0/preview.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 1,
#      'car': 2,
#      'lat': -37.855926,
#      'lng': 145.306835,
#      'land': '726',
#      'list_date': '2022-03-29',
#      'list_price': '',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19749507861,
#      'agent_code': 'VIC121873'},
#     {'state': 'VIC',
#      'address': '9 Maurice Road',
#      'suburb_code': 'gruyere-vic-3770',
#      'suburb_name': 'Gruyere',
#      'postcode': '3770',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUS9rUFh3OVZWM24zWU5ubjN6dTJBSHY2T29sQmFkMnhObGoxVjNObFBIdnhMVFQ2Nmg0L25OWXowRmpYcElmOXM4Mi9BYjBEYldIUmQ3MVpnZGpCaHZRTWpmTmpvd2ptbDZZUHZnSlM1M09nPT0/preview.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 2,
#      'car': 0,
#      'lat': -37.762987,
#      'lng': 145.430074,
#      'land': '',
#      'list_date': '2022-03-29',
#      'list_price': '$1,950,000 - $2,145,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19743707861,
#      'agent_code': 'VIC139008'},
#     {'state': 'VIC',
#      'address': '2 Steel Road',
#      'suburb_code': 'hamilton-vic-3300',
#      'suburb_name': 'Hamilton',
#      'postcode': '3300',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQU2crdnF2c2lkaEMxMU5aRllpQlBTbWR4RnFhOVJpZUJnS05jNDdMNzYyWXZxM3l6OXZGS1EvQjkzL2RheEVGUEE1UXRHeU84UnV0bnpWS210Y1p0S0hhRjNGU0JRcjdGa3RWdWpiNEpEQTJ3PT0/preview.jpg',
#      'type': 'house',
#      'bed': 1,
#      'bath': 1,
#      'car': 0,
#      'lat': -37.7531537,
#      'lng': 142.0323321,
#      'land': '746',
#      'list_date': '2022-03-29',
#      'list_price': '$290,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19781807861,
#      'agent_code': 'VIC295577'},
#     {'state': 'VIC',
#      'address': '13 Jenner Court',
#      'suburb_code': 'hampton-park-vic-3976',
#      'suburb_name': 'Hampton Park',
#      'postcode': '3976',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUWt6S2x2OTU4Ni9pOFplZjVaQVlpVU9TTTAvbkIrUlh6dEc3bXp0RWhZbjRoUTgvTTVLeStzcXV0WGVleFZBT3pvYS9LK09HMk16cHZhK2ROaHY4OU14WUF3bHBDSHhIK2lLSngyaFJ2SnJBPT0/preview.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 1,
#      'car': 2,
#      'lat': -38.031037,
#      'lng': 145.248316,
#      'land': '740',
#      'list_date': '2022-03-29',
#      'list_price': '$620,000 - $660,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19724017861,
#      'agent_code': 'VIC80384'},
#     {'state': 'VIC',
#      'address': '51 Galilee Drive',
#      'suburb_code': 'sandhurst-vic-3977',
#      'suburb_name': 'Sandhurst',
#      'postcode': '3977',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUmFVWitoU3N3cllzNWRFOVRaMGdrWk9oTE1JTWRTdldRV3JJODFBaGpRTy9ETkdUVFJSTVh5VnEvSTJvWmtwRm1qN25Ub3V3cWFLTmNwUEhaRWJFUTRyMGV1MTk4NzcrUVQzZWlwUVF2aUR3PT0/preview.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 2,
#      'car': 2,
#      'lat': -38.0826523,
#      'lng': 145.1937243,
#      'land': '823',
#      'list_date': '2022-03-29',
#      'list_price': '$1,280,000 - $1,380,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19705317861,
#      'agent_code': 'VIC281758'},
#     {'state': 'VIC',
#      'address': '1/44 Governors Road',
#      'suburb_code': 'crib-point-vic-3919',
#      'suburb_name': 'Crib Point',
#      'postcode': '3919',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQU0FoN2MwMGJrbmg4blNaQ3lpSEo1WlBMZjljdEtJaE1oNmxUTkFDUkRjcS9kRXNmZlhVWnJzYmREOW9jbGVJVkZHVXljN3JNazYzWnEzS2ZRbUtSdUgxVUVLYURhVTF0emVIMlhOR0ZMUlBRPT0/preview.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 1,
#      'car': 2,
#      'lat': -38.357867,
#      'lng': 145.204599,
#      'land': '866',
#      'list_date': '2022-03-29',
#      'list_price': '$850000 - $895000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19743417861,
#      'agent_code': 'VIC142166'},
#     {'state': 'VIC',
#      'address': '631 Plenty Road',
#      'suburb_code': 'preston-vic-3072',
#      'suburb_name': 'Preston',
#      'postcode': '3072',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUlpVRGZwTjhmN2llenM2TGk1VHhBRWxBaDlnUjZYZ2JCQjdaOHVpUTB2RDJLRGVZa0JWZ1FzdndVbWh4T3JQdkthK2F5c3JPNWM2QkFCZ1ZsS0d4ZW93NGxNRHNkMkJlcEVJTitpazg3YXRBPT0/preview.jpg',
#      'type': 'apartment',
#      'bed': 3,
#      'bath': 2,
#      'car': 1,
#      'lat': -37.731522,
#      'lng': 145.0141819,
#      'land': '',
#      'list_date': '2022-03-29',
#      'list_price': '$670,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19781517861,
#      'agent_code': 'VIC352787'},
#     {'state': 'VIC',
#      'address': '69 Elstar Road',
#      'suburb_code': 'narre-warren-south-vic-3805',
#      'suburb_name': 'Narre Warren South',
#      'postcode': '3805',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUmhSTHFQeFBKWnF1NkJDWlZOZCsxeFRIeER3KzJQYlVSMTcvSzNPY2tva1FsYTMvNnYvbTBZcWpUTDl1Y0xMZENBMWdNTDYwemFMNU5YMitsUFZySExYN0gxbDZBd2RMVHFjQ1M1bzlwK093PT0/preview.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 2,
#      'car': 2,
#      'lat': -38.003822,
#      'lng': 145.294958,
#      'land': '503',
#      'list_date': '2022-03-29',
#      'list_price': '$690,000 - $758,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19747517861,
#      'agent_code': 'VIC282235'},
#     {'state': 'VIC',
#      'address': 'Lot 2, 36A Jamieson Street',
#      'suburb_code': 'daylesford-vic-3460',
#      'suburb_name': 'Daylesford',
#      'postcode': '3460',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUVd5RDlycjVod2tOZlVyVC91N3lyNitweTJhVFpuN2NHMEJhNWVucm9xQTBuN053MGJNemFRcE5aeEFPc2tQVEVJZ0J2Zjc3dHRyU0U2QTBDUjZWaXNSUkVhK0pKbW1FVW03ajI0UHJvR2JBPT0/preview.jpg',
#      'type': 'residential land',
#      'bed': 0,
#      'bath': 0,
#      'car': 0,
#      'lat': -37.3359119,
#      'lng': 144.147072,
#      'land': '415',
#      'list_date': '2022-03-29',
#      'list_price': '$390,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 14887303266,
#      'agent_code': 'VIC258298'},
#     {'state': 'VIC',
#      'address': '19B Friendship Square',
#      'suburb_code': 'cheltenham-vic-3192',
#      'suburb_name': 'Cheltenham',
#      'postcode': '3192',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUjFMcm8rZmgyRjUwelU2MGNzREVkVDBjMzAxS3dkQXNSeHRCbHAwQ0pJTmx3N1VZQmtsYUxpY2txYnVlVVV0V3JIMUlrM29lT3NOdDNTU2t0aCtMTlBlYjhkcU5LaFhNNlY5QmJaWlRPM1FBPT0/preview.jpg',
#      'type': 'townhouse',
#      'bed': 4,
#      'bath': 2,
#      'car': 2,
#      'lat': -37.959688,
#      'lng': 145.066564,
#      'land': '',
#      'list_date': '2022-03-29',
#      'list_price': '$1,150,000 - $1,250,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19728817861,
#      'agent_code': 'VIC227582'},
#     {'state': 'VIC',
#      'address': '631 Plenty Road',
#      'suburb_code': 'preston-vic-3072',
#      'suburb_name': 'Preston',
#      'postcode': '3072',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUWx4RVdhUGNNTlV5SjUrTzRRY21nVGJOSFdBbG5jejJXalBqUmljNmpMdlN4QlNJaHVWMGxKOWNUeGZjQUIwaEt0TlFQRTVFT0M0Y2I2TUl6TVBGZDNhNnhTSG5DVGJjYnpTK2g0SkRHR1VBPT0/preview.jpg',
#      'type': 'apartment',
#      'bed': 2,
#      'bath': 1,
#      'car': 1,
#      'lat': -37.731522,
#      'lng': 145.0141819,
#      'land': '',
#      'list_date': '2022-03-29',
#      'list_price': '$599,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19701917861,
#      'agent_code': 'VIC352787'},
#     {'state': 'VIC',
#      'address': '4 Riesling Street',
#      'suburb_code': 'wollert-vic-3750',
#      'suburb_name': 'Wollert',
#      'postcode': '3750',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQVEF2WHd6TDBmL3NTQmlJZkRuSlRtemlzWnFyYmRxUzdtb1F1d2NqSWlIWEhrSGl1bG90NkIrYkdiU1ZJVVFwb1pmZnVPNVgxM2xWRUoxczhDNTBEK0FKMnJ5TFlZdW5oZU42czdWbUhxdWJnPT0/preview.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 2,
#      'car': 2,
#      'lat': -37.5934511,
#      'lng': 144.9976267,
#      'land': '',
#      'list_date': '2022-03-29',
#      'list_price': '',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19722027861,
#      'agent_code': 'VIC283802'},
#     {'state': 'VIC',
#      'address': '375 Patterson Road',
#      'suburb_code': 'clyde-north-vic-3978',
#      'suburb_name': 'Clyde North',
#      'postcode': '3978',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUm9xanAwcDE5WFBkaVdEVDZsUkdFcGlZOFhCZWtmcUQvTVJtc1cvUmtWR0hxSUNwZVlTY3pDb0tzUUxrMEtwQ0dkeVpIUkVYaGN4b0ZoSTdDUGhyaElPVThrV2M2K01aT3h1cEVHODFEUDlnPT0/preview.jpg',
#      'type': 'project',
#      'bed': 0,
#      'bath': 0,
#      'car': 0,
#      'lat': -38.1236779,
#      'lng': 145.3696515,
#      'land': '',
#      'list_date': '2022-03-29',
#      'list_price': '',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 111932762236,
#      'agent_code': 'VIC338849'},
#     {'state': 'VIC',
#      'address': '65 Pakington Street',
#      'suburb_code': 'kew-vic-3101',
#      'suburb_name': 'Kew',
#      'postcode': '3101',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUjErN3ViUEdpdzJiYWNkQXowaGNUSU5DN3FEbERnaWEwOG1adzQwUnZCL1JveTgyeFVKczVWVVBWcnBvZDZDSE5rS3JXaVk3aXl5ZitPcWtZZnBWTlVUcWg4Mk53SXVnbThCdUk1aWFxMnN3PT0/preview.jpg',
#      'type': 'apartment',
#      'bed': 3,
#      'bath': 3,
#      'car': 2,
#      'lat': -37.8002,
#      'lng': 145.035036,
#      'land': '',
#      'list_date': '2022-03-29',
#      'list_price': '',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19703327861,
#      'agent_code': 'VIC352787'},
#     {'state': 'VIC',
#      'address': '22 Westwood Drive',
#      'suburb_code': 'mooroopna-vic-3629',
#      'suburb_name': 'Mooroopna',
#      'postcode': '3629',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQU29MeVFXQUwrNXZuMysydG1Wc3RsUEc5dkR2Q1gzc0lTdm42M0FDYmxRVTBneTVHUXdJMHVwRHlqaloxTy9ZMzU4TVo1SS9jUXVvc2Z2ZEpnTy9rVkRSamkzTGIwYmtldnNyMFo4QmRVQVRRPT0/preview.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 2,
#      'car': 2,
#      'lat': -36.3949092,
#      'lng': 145.3409518,
#      'land': '815',
#      'list_date': '2022-03-29',
#      'list_price': '$545,000 - $585,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19785327861,
#      'agent_code': 'VIC174432'},
#     {'state': 'VIC',
#      'address': '4 Rosalie Avenue',
#      'suburb_code': 'cranbourne-vic-3977',
#      'suburb_name': 'Cranbourne',
#      'postcode': '3977',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUWNJZVY3NEFIMEpHcXhQNXE2all0U0dKSTRoWklRT0h5VWVRbGNlanI2dVBwbWR6WFlPcjFjeEJLdWc4cUROSnpvV3BXSHh6elAycmFNaS9TQURTR3ZuckpGSGNuckx3Ymc5UzRvOVk3bWZRPT0/preview.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 2,
#      'car': 4,
#      'lat': -38.096109,
#      'lng': 145.272467,
#      'land': '700',
#      'list_date': '2022-03-29',
#      'list_price': '$670,000 - $730,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19741427861,
#      'agent_code': 'VIC282235'},
#     {'state': 'VIC',
#      'address': '32/79 Lancefield Drive',
#      'suburb_code': 'caroline-springs-vic-3023',
#      'suburb_name': 'Caroline Springs',
#      'postcode': '3023',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQU3RkMTBFVGRxTUljM0xEbXgvdURQTlVUNkJ1T3pZOHBrMjBpdE54a2ppQ1NiUVlEbEk1ZlpTaUxNQlNWUTA0RmhINlRka3h2VEdxUE10U0w1TUczeVNtZ0kvWmQxOFhLQkwzSVQrclFCSytnPT0/preview.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 2,
#      'car': 2,
#      'lat': -37.7102097,
#      'lng': 144.737178,
#      'land': '',
#      'list_date': '2022-03-29',
#      'list_price': '$530,000 - $570,000',
#      'days_on_market': 0,
#      'gnaf_pid': '',
#      'pu_id': 19707427861,
#      'agent_code': 'VIC353177'}],
#    'meta': {'pagination': {'total': 41102,
#      'count': 50,
#      'per_page': 50,
#      'current_page': 1,
#      'total_pages': 823,
#      'links': {'next': 'https://api2.aupropertyreport.com/api/state/vic/buy?page=2'}}}}}}

# %% [markdown]
# # Sate for Sold Properties: 注意有 3000 pages+

# %%
state_sold_url = f"https://api2.aupropertyreport.com/api/state/{state}/sold"

# GET Request
state_sold_request = requests.get(state_sold_url,headers=auth,params={"limit":"50"})
state_sold_respond = state_sold_request.json()
state_sold_respond
# Out:
# {'data': {'state_code': 'VIC',
#   'sold': {'data': [{'state': 'VIC',
#      'address': '227 Ballarat Carngham Road',
#      'suburb_code': 'winter-valley-vic-3358',
#      'suburb_name': 'Winter Valley',
#      'postcode': '3358',
#      'image': 'https://farm66.static.flickr.com/65535/51929989340_d311638e9e.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 2,
#      'car': 2,
#      'lat': -37.5672084,
#      'lng': 143.7853336,
#      'land': '567',
#      'sold_date': '2022-03-29',
#      'sold_price': 565000,
#      'gnaf_pid': '',
#      'pu_id': 39781276641,
#      'agent_code': 'VIC148',
#      'sold_price_display': '$581,000 - $607,000'},
#     {'state': 'VIC',
#      'address': '9 Souter Avenue',
#      'suburb_code': 'kalkallo-vic-3064',
#      'suburb_name': 'Kalkallo',
#      'postcode': '3064',
#      'image': 'https://farm66.static.flickr.com/65535/51967038324_bd3a606d87.jpg',
#      'type': 'residential land',
#      'bed': 0,
#      'bath': 0,
#      'car': 0,
#      'lat': -37.5235348,
#      'lng': 144.9633988,
#      'land': '512',
#      'sold_date': '2022-03-29',
#      'sold_price': 466000,
#      'gnaf_pid': '',
#      'pu_id': 34849047956,
#      'agent_code': 'VIC325676',
#      'sold_price_display': '$441,000 - $459,000'},
#     {'state': 'VIC',
#      'address': '9 Belinda Close',
#      'suburb_code': 'kilsyth-vic-3137',
#      'suburb_name': 'Kilsyth',
#      'postcode': '3137',
#      'image': 'https://farm66.static.flickr.com/65535/51967838774_647f4b1110.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 1,
#      'car': 1,
#      'lat': -37.8135497,
#      'lng': 145.3135586,
#      'land': '483',
#      'sold_date': '2022-03-29',
#      'sold_price': 775000,
#      'gnaf_pid': '',
#      'pu_id': 39764256451,
#      'agent_code': 'VIC10425',
#      'sold_price_display': '$735,000 - $765,000'},
#     {'state': 'VIC',
#      'address': '47 Station Street',
#      'suburb_code': 'sunbury-vic-3429',
#      'suburb_name': 'Sunbury',
#      'postcode': '3429',
#      'image': 'https://farm66.static.flickr.com/65535/51966554117_01e7860b1b.jpg',
#      'type': 'house',
#      'bed': 2,
#      'bath': 2,
#      'car': 1,
#      'lat': -37.5832037,
#      'lng': 144.730788,
#      'land': '',
#      'sold_date': '2022-03-29',
#      'sold_price': 500000,
#      'gnaf_pid': '',
#      'pu_id': 39760343861,
#      'agent_code': 'VIC120923',
#      'sold_price_display': '$470,000 - $490,000'},
#     {'state': 'VIC',
#      'address': '16 Atlantic Drive',
#      'suburb_code': 'indented-head-vic-3223',
#      'suburb_name': 'Indented Head',
#      'postcode': '3223',
#      'image': 'https://farm66.static.flickr.com/65535/51966555872_99eb0d4528.jpg',
#      'type': 'residential land',
#      'bed': 0,
#      'bath': 0,
#      'car': 0,
#      'lat': -38.1385864,
#      'lng': 144.7011326,
#      'land': '512',
#      'sold_date': '2022-03-29',
#      'sold_price': 500000,
#      'gnaf_pid': '',
#      'pu_id': 34817222856,
#      'agent_code': 'VIC330748',
#      'sold_price_display': '$470,000 - $490,000'},
#     {'state': 'VIC',
#      'address': 'G01/1 Oak Avenue',
#      'suburb_code': 'boronia-vic-3155',
#      'suburb_name': 'Boronia',
#      'postcode': '3155',
#      'image': 'https://farm66.static.flickr.com/65535/51968121985_920b94ab8a.jpg',
#      'type': 'apartment',
#      'bed': 2,
#      'bath': 1,
#      'car': 1,
#      'lat': -37.8578437,
#      'lng': 145.2866413,
#      'land': '',
#      'sold_date': '2022-03-29',
#      'sold_price': 481000,
#      'gnaf_pid': '',
#      'pu_id': 39787637941,
#      'agent_code': 'VIC10425',
#      'sold_price_display': '$455,000 - $473,000'},
#     {'state': 'Vic',
#      'address': '3 Crystal Gardens',
#      'suburb_code': 'cranbourne-west-vic-3977',
#      'suburb_name': 'Cranbourne West',
#      'postcode': '3977',
#      'image': 'https://farm66.static.flickr.com/65535/51966613387_134bdf2916.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 1,
#      'car': 2,
#      'lat': -38.105024,
#      'lng': 145.258023,
#      'land': '243',
#      'sold_date': '2022-03-29',
#      'sold_price': 545000,
#      'gnaf_pid': '',
#      'pu_id': 39709725651,
#      'agent_code': 'VIC291482',
#      'sold_price_display': '$510,000 - $534,000'},
#     {'state': 'Vic',
#      'address': '95/62 Punt Road',
#      'suburb_code': 'johnsonville-vic-3902',
#      'suburb_name': 'Johnsonville',
#      'postcode': '3902',
#      'image': 'https://farm66.static.flickr.com/65535/51967913839_d0fed2f899.jpg',
#      'type': 'unit',
#      'bed': 2,
#      'bath': 1,
#      'car': 1,
#      'lat': -37.8257995,
#      'lng': 147.8293062,
#      'land': '',
#      'sold_date': '2022-03-29',
#      'sold_price': 240000,
#      'gnaf_pid': '',
#      'pu_id': 39741671930,
#      'agent_code': 'VIC200239',
#      'sold_price_display': '$250,000 - $262,000'},
#     {'state': 'Vic',
#      'address': '8 Penrose Mews',
#      'suburb_code': 'hillside-vic-3875',
#      'suburb_name': 'Hillside',
#      'postcode': '3037',
#      'image': 'https://farm66.static.flickr.com/65535/51966632822_5b19398aed.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 2,
#      'car': 2,
#      'lat': -37.6878602,
#      'lng': 144.74342,
#      'land': '420',
#      'sold_date': '2022-03-29',
#      'sold_price': 762000,
#      'gnaf_pid': '',
#      'pu_id': 39749281941,
#      'agent_code': 'VIC3897',
#      'sold_price_display': '$784,000 - $816,000'},
#     {'state': 'VIC',
#      'address': '1211/35 Albert Road',
#      'suburb_code': 'melbourne-vic-3004',
#      'suburb_name': 'Melbourne',
#      'postcode': '3004',
#      'image': 'https://farm66.static.flickr.com/65535/51968015771_595aae2728.jpg',
#      'type': 'apartment',
#      'bed': 2,
#      'bath': 1,
#      'car': 1,
#      'lat': -37.834663,
#      'lng': 144.9719325,
#      'land': '',
#      'sold_date': '2022-03-29',
#      'sold_price': 0,
#      'gnaf_pid': '',
#      'pu_id': 39734002280,
#      'agent_code': 'VIC318746'},
#     {'state': 'VIC',
#      'address': '35-37 Minnimurra Road',
#      'suburb_code': 'rye-vic-3941',
#      'suburb_name': 'Rye',
#      'postcode': '3941',
#      'image': 'https://farm66.static.flickr.com/65535/51967652521_ec88f00bde.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 2,
#      'car': 2,
#      'lat': -38.371214,
#      'lng': 144.810805,
#      'land': '1974',
#      'sold_date': '2022-03-29',
#      'sold_price': 2440000,
#      'gnaf_pid': '',
#      'pu_id': 39728010130,
#      'agent_code': 'VIC14870',
#      'sold_price_display': '$2,400,000 - $2,512,000'},
#     {'state': 'VIC',
#      'address': '10 Alexander Circle',
#      'suburb_code': 'patterson-lakes-vic-3197',
#      'suburb_name': 'Patterson Lakes',
#      'postcode': '3197',
#      'image': 'https://farm66.static.flickr.com/65535/51966650452_a9d199a6b7.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 2,
#      'car': 2,
#      'lat': -38.0595365,
#      'lng': 145.1405613,
#      'land': '540',
#      'sold_date': '2022-03-29',
#      'sold_price': 1355000,
#      'gnaf_pid': '',
#      'pu_id': 39749854541,
#      'agent_code': 'VIC7655',
#      'sold_price_display': '$1,328,000 - $1,392,000'},
#     {'state': 'VIC',
#      'address': '52 Murray Street',
#      'suburb_code': 'rye-vic-3941',
#      'suburb_name': 'Rye',
#      'postcode': '3941',
#      'image': 'https://farm66.static.flickr.com/65535/51968217015_48c2ccbfeb.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 2,
#      'car': 1,
#      'lat': -38.370726,
#      'lng': 144.789622,
#      'land': '',
#      'sold_date': '2022-03-29',
#      'sold_price': 0,
#      'gnaf_pid': '',
#      'pu_id': 39743785641,
#      'agent_code': 'VIC274016'},
#     {'state': 'VIC',
#      'address': '17 Woodlands Road',
#      'suburb_code': 'cranbourne-south-vic-3977',
#      'suburb_name': 'Cranbourne South',
#      'postcode': '3977',
#      'image': 'https://farm66.static.flickr.com/65535/51968218350_2ea0c5ea02.jpg',
#      'type': 'acreage-semi-rural',
#      'bed': 4,
#      'bath': 1,
#      'car': 2,
#      'lat': -38.1344622,
#      'lng': 145.2371871,
#      'land': '3952',
#      'sold_date': '2022-03-29',
#      'sold_price': 0,
#      'gnaf_pid': '',
#      'pu_id': 39764899751,
#      'agent_code': 'VIC300963'},
#     {'state': 'VIC',
#      'address': '18 Correa Place',
#      'suburb_code': 'inverloch-vic-3996',
#      'suburb_name': 'Inverloch',
#      'postcode': '3996',
#      'image': 'https://farm66.static.flickr.com/65535/51967658671_fa43c36267.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 2,
#      'car': 2,
#      'lat': -38.6300128,
#      'lng': 145.7146935,
#      'land': '574',
#      'sold_date': '2022-03-29',
#      'sold_price': 1175000,
#      'gnaf_pid': '',
#      'pu_id': 39795526590,
#      'agent_code': 'VIC1258',
#      'sold_price_display': '$1,154,000 - $1,210,000'},
#     {'state': 'VIC',
#      'address': '2346 Seymour Pyalong Road',
#      'suburb_code': 'pyalong-vic-3521',
#      'suburb_name': 'Pyalong',
#      'postcode': '3521',
#      'image': 'https://farm66.static.flickr.com/65535/51968221045_cbfe2597c4.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 2,
#      'car': 2,
#      'lat': -37.1237501,
#      'lng': 144.8749513,
#      'land': '84206',
#      'sold_date': '2022-03-29',
#      'sold_price': 0,
#      'gnaf_pid': '',
#      'pu_id': 39726986751,
#      'agent_code': 'VIC141250'},
#     {'state': 'VIC',
#      'address': '42 Clyde Avenue',
#      'suburb_code': 'st-leonards-vic-3223',
#      'suburb_name': 'St Leonards',
#      'postcode': '3223',
#      'image': 'https://farm66.static.flickr.com/65535/51968222330_5b44525945.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 2,
#      'car': 3,
#      'lat': -38.1839968,
#      'lng': 144.7095123,
#      'land': '763',
#      'sold_date': '2022-03-29',
#      'sold_price': 1000000,
#      'gnaf_pid': '',
#      'pu_id': 39705548141,
#      'agent_code': 'VIC330748',
#      'sold_price_display': '$972,000 - $1,020,000'},
#     {'state': 'VIC',
#      'address': '15A Henry Street',
#      'suburb_code': 'doncaster-vic-3108',
#      'suburb_name': 'Doncaster',
#      'postcode': '3108',
#      'image': 'https://farm66.static.flickr.com/65535/51967662871_e1954a13d3.jpg',
#      'type': 'townhouse',
#      'bed': 3,
#      'bath': 2,
#      'car': 2,
#      'lat': -37.7750793,
#      'lng': 145.1290847,
#      'land': '',
#      'sold_date': '2022-03-29',
#      'sold_price': 991800,
#      'gnaf_pid': '',
#      'pu_id': 39764727041,
#      'agent_code': 'VIC322467',
#      'sold_price_display': '$1,037,000 - $1,075,000'},
#     {'state': 'VIC',
#      'address': '11 Lancia Court',
#      'suburb_code': 'epping-vic-3076',
#      'suburb_name': 'Epping',
#      'postcode': '3076',
#      'image': 'https://farm66.static.flickr.com/65535/51967728283_a27b33ea60.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 1,
#      'car': 2,
#      'lat': -37.635748,
#      'lng': 145.035581,
#      'land': '565',
#      'sold_date': '2022-03-29',
#      'sold_price': 722500,
#      'gnaf_pid': '',
#      'pu_id': 39720097441,
#      'agent_code': 'VIC163242',
#      'sold_price_display': '$752,000 - $784,000'},
#     {'state': 'VIC',
#      'address': '6 Wicket Road',
#      'suburb_code': 'clyde-vic-3978',
#      'suburb_name': 'Clyde',
#      'postcode': '3978',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQVDVoZnMrTDhPRGIzdTBrdHhOcTUvcGwyQzJMOVdjeWRzZmoyWXBoUytack9Yb0Rmbi9KZ0cwS3VYQXJ2OUltZmtwNjB2aWJzOEpEYmJNZ3lUOC9iQnlpcGpnWXNza1NucEhkR0RGa2hnVHlBPT0/preview.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 2,
#      'car': 2,
#      'lat': -38.1283673,
#      'lng': 145.3166566,
#      'land': '350',
#      'sold_date': '2022-03-29',
#      'sold_price': 720000,
#      'gnaf_pid': '',
#      'pu_id': 39720398941,
#      'agent_code': 'VIC312180',
#      'sold_price_display': '$752,000 - $784,000'},
#     {'state': 'VIC',
#      'address': '23 Fairway Drive',
#      'suburb_code': 'traralgon-vic-3844',
#      'suburb_name': 'Traralgon',
#      'postcode': '3844',
#      'image': 'https://farm66.static.flickr.com/65535/51966664357_cb7d09e068.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 2,
#      'car': 2,
#      'lat': -38.2093027,
#      'lng': 146.53284,
#      'land': '1221',
#      'sold_date': '2022-03-29',
#      'sold_price': 720000,
#      'gnaf_pid': '',
#      'pu_id': 39791990710,
#      'agent_code': 'VIC297673',
#      'sold_price_display': '$752,000 - $784,000'},
#     {'state': 'VIC',
#      'address': '41 The Boulevard',
#      'suburb_code': 'sale-vic-3850',
#      'suburb_name': 'Sale',
#      'postcode': '3850',
#      'image': 'https://farm66.static.flickr.com/65535/51967734823_278bf35e86.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 2,
#      'car': 2,
#      'lat': -38.0853079,
#      'lng': 147.051933,
#      'land': '1016',
#      'sold_date': '2022-03-29',
#      'sold_price': 670000,
#      'gnaf_pid': '',
#      'pu_id': 39703965741,
#      'agent_code': 'VIC16608',
#      'sold_price_display': '$689,000 - $719,000'},
#     {'state': 'VIC',
#      'address': '2335 Great Ocean Road',
#      'suburb_code': 'hordern-vale-vic-3238',
#      'suburb_name': 'Hordern Vale',
#      'postcode': '3238',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUUdxN0ZnS3pQUllLSDZjN0FKN01mR2tpZHZ0ZmIwRzhORHREcXlQc0VyM2RXSkdJVllUdGt4M2RuRjFjanllNm9GUU1NaVdIRkVsVElvb0swNU5US09sdUVWN053NkdBWjYrbU9WVHJBcWJBPT0/preview.jpg',
#      'type': 'other',
#      'bed': 3,
#      'bath': 1,
#      'car': 3,
#      'lat': -38.7741483,
#      'lng': 143.5091176,
#      'land': '5676',
#      'sold_date': '2022-03-29',
#      'sold_price': 0,
#      'gnaf_pid': '',
#      'pu_id': 311135082343,
#      'agent_code': 'VIC6608'},
#     {'state': 'VIC',
#      'address': '61 Wyndham Street',
#      'suburb_code': 'stratford-vic-3862',
#      'suburb_name': 'Stratford',
#      'postcode': '3862',
#      'image': 'https://farm66.static.flickr.com/65535/51967955549_fe9260edf7.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 2,
#      'car': 2,
#      'lat': -37.9592966,
#      'lng': 147.0869467,
#      'land': '770',
#      'sold_date': '2022-03-29',
#      'sold_price': 535000,
#      'gnaf_pid': '',
#      'pu_id': 39785319030,
#      'agent_code': 'VIC16608',
#      'sold_price_display': '$549,000 - $573,000'},
#     {'state': 'VIC',
#      'address': 'Address available on request',
#      'suburb_code': 'epping-vic-3076',
#      'suburb_name': 'Epping',
#      'postcode': '3076',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUk1CK1RmRFdaM2c2NnQ4UVdqMzlHdnpYeE9WaWdYUCt0bDRxVUxockhTVXdWdnByN0ZXK1pnZzJqMm1WR1RyWDlZdVpRcFF1WHBoK2R3QzdCQldEQVZFaXBOYU1ScXZNNVEwQ0FBRG5ZUkZBPT0/preview.jpg',
#      'type': 'residential land',
#      'bed': 0,
#      'bath': 0,
#      'car': 0,
#      'lat': 0,
#      'lng': 0,
#      'land': '537',
#      'sold_date': '2022-03-29',
#      'sold_price': 0,
#      'gnaf_pid': '',
#      'pu_id': 34845964056},
#     {'state': 'VIC',
#      'address': '3/2a Triplett Avenue',
#      'suburb_code': False,
#      'suburb_name': 'Ascot',
#      'postcode': '3551',
#      'image': 'https://farm66.static.flickr.com/65535/51967958309_d73b8e838a.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 2,
#      'car': 2,
#      'lat': -36.6990174,
#      'lng': 144.3264457,
#      'land': '292',
#      'sold_date': '2022-03-29',
#      'sold_price': 0,
#      'gnaf_pid': '',
#      'pu_id': 39766673861,
#      'agent_code': 'VIC274655'},
#     {'state': 'VIC',
#      'address': '2/2a Triplett Avenue',
#      'suburb_code': False,
#      'suburb_name': 'Ascot',
#      'postcode': '3551',
#      'image': 'https://farm66.static.flickr.com/65535/51967959744_4f19bca851.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 2,
#      'car': 2,
#      'lat': -36.6990174,
#      'lng': 144.3264457,
#      'land': '291',
#      'sold_date': '2022-03-29',
#      'sold_price': 0,
#      'gnaf_pid': '',
#      'pu_id': 39705073861,
#      'agent_code': 'VIC274655'},
#     {'state': 'VIC',
#      'address': '14 Rundell Street',
#      'suburb_code': 'ararat-vic-3377',
#      'suburb_name': 'Ararat',
#      'postcode': '3377',
#      'image': 'https://farm66.static.flickr.com/65535/51967961064_50fb8ba42a.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 1,
#      'car': 4,
#      'lat': -37.2866164,
#      'lng': 142.9341746,
#      'land': '1020',
#      'sold_date': '2022-03-29',
#      'sold_price': 432000,
#      'gnaf_pid': '',
#      'pu_id': 39787836241,
#      'agent_code': 'VIC190098',
#      'sold_price_display': '$439,000 - $457,000'},
#     {'state': 'VIC',
#      'address': 'Address available on request',
#      'suburb_code': 'epping-vic-3076',
#      'suburb_name': 'Epping',
#      'postcode': '3076',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUzdNN1kzNTFMWUIycm9yUkl4eXBoNlNZOFUvNGV2VUovTkQ3clNFMUVwTHo5Q1RrcTFndk9mYXFLTVVkR3Uxa2VUcm10OWJucUppWk9Nc2VBZFZTcE5WS1BuZmVVWVZkcjZYa2V5YWQvTTB3PT0/preview.jpg',
#      'type': 'residential land',
#      'bed': 0,
#      'bath': 0,
#      'car': 0,
#      'lat': 0,
#      'lng': 0,
#      'land': '422',
#      'sold_date': '2022-03-29',
#      'sold_price': 0,
#      'gnaf_pid': '',
#      'pu_id': 34847664056},
#     {'state': 'VIC',
#      'address': '6/17 Bradbury Street',
#      'suburb_code': 'brown-hill-vic-3350',
#      'suburb_name': 'Brown Hill',
#      'postcode': '3350',
#      'image': 'https://farm66.static.flickr.com/65535/51968243275_fed9e1983a.jpg',
#      'type': 'unit',
#      'bed': 2,
#      'bath': 1,
#      'car': 1,
#      'lat': -37.5562383,
#      'lng': 143.900314,
#      'land': '212',
#      'sold_date': '2022-03-29',
#      'sold_price': 420000,
#      'gnaf_pid': '',
#      'pu_id': 39783850851,
#      'agent_code': 'VIC146947',
#      'sold_price_display': '$439,000 - $457,000'},
#     {'state': 'VIC',
#      'address': 'Address available on request',
#      'suburb_code': 'epping-vic-3076',
#      'suburb_name': 'Epping',
#      'postcode': '3076',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQVElvZDA2d3U2QTVUV1FEYnNIYnF5VXd5SUpYU0NZUlM3TzhtbDBrM095cDMrVzlEd0lXM25uZ2pjMkF2dkdHeFdSc0MwNUpvNVkxRzY1WUwrWmlROHJ1LysyMEErY2ZuY2x4dlZOcXBpNDRnPT0/preview.jpg',
#      'type': 'residential land',
#      'bed': 0,
#      'bath': 0,
#      'car': 0,
#      'lat': 0,
#      'lng': 0,
#      'land': '419',
#      'sold_date': '2022-03-29',
#      'sold_price': 0,
#      'gnaf_pid': '',
#      'pu_id': 34841864056},
#     {'state': 'VIC',
#      'address': 'Address available on request',
#      'suburb_code': 'epping-vic-3076',
#      'suburb_name': 'Epping',
#      'postcode': '3076',
#      'image': 'https://farm66.static.flickr.com/65535/51967687061_946c754c84.jpg',
#      'type': 'residential land',
#      'bed': 0,
#      'bath': 0,
#      'car': 0,
#      'lat': 0,
#      'lng': 0,
#      'land': '404',
#      'sold_date': '2022-03-29',
#      'sold_price': 0,
#      'gnaf_pid': '',
#      'pu_id': 34887518156},
#     {'state': 'VIC',
#      'address': 'Address available on request',
#      'suburb_code': 'epping-vic-3076',
#      'suburb_name': 'Epping',
#      'postcode': '3076',
#      'image': 'https://farm66.static.flickr.com/65535/51967752748_fefc2dcea0.jpg',
#      'type': 'residential land',
#      'bed': 0,
#      'bath': 0,
#      'car': 0,
#      'lat': 0,
#      'lng': 0,
#      'land': '263',
#      'sold_date': '2022-03-29',
#      'sold_price': 0,
#      'gnaf_pid': '',
#      'pu_id': 34822518156},
#     {'state': 'VIC',
#      'address': 'Address available on request',
#      'suburb_code': 'epping-vic-3076',
#      'suburb_name': 'Epping',
#      'postcode': '3076',
#      'image': 'https://farm66.static.flickr.com/65535/51967754303_30407ee15f.jpg',
#      'type': 'residential land',
#      'bed': 0,
#      'bath': 0,
#      'car': 0,
#      'lat': 0,
#      'lng': 0,
#      'land': '263',
#      'sold_date': '2022-03-29',
#      'sold_price': 0,
#      'gnaf_pid': '',
#      'pu_id': 34801418156},
#     {'state': 'VIC',
#      'address': 'Address available on request',
#      'suburb_code': 'epping-vic-3076',
#      'suburb_name': 'Epping',
#      'postcode': '3076',
#      'image': 'https://farm66.static.flickr.com/65535/51968252770_46fc0e4b65.jpg',
#      'type': 'residential land',
#      'bed': 0,
#      'bath': 0,
#      'car': 0,
#      'lat': 0,
#      'lng': 0,
#      'land': '263',
#      'sold_date': '2022-03-29',
#      'sold_price': 0,
#      'gnaf_pid': '',
#      'pu_id': 34828318156},
#     {'state': 'VIC',
#      'address': 'Address available on request',
#      'suburb_code': 'epping-vic-3076',
#      'suburb_name': 'Epping',
#      'postcode': '3076',
#      'image': 'https://farm66.static.flickr.com/65535/51966688867_5980c4c327.jpg',
#      'type': 'residential land',
#      'bed': 0,
#      'bath': 0,
#      'car': 0,
#      'lat': 0,
#      'lng': 0,
#      'land': '263',
#      'sold_date': '2022-03-29',
#      'sold_price': 0,
#      'gnaf_pid': '',
#      'pu_id': 34849418156},
#     {'state': 'VIC',
#      'address': 'Address available on request',
#      'suburb_code': 'epping-vic-3076',
#      'suburb_name': 'Epping',
#      'postcode': '3076',
#      'image': 'https://farm66.static.flickr.com/65535/51966690292_120d593b3d.jpg',
#      'type': 'residential land',
#      'bed': 0,
#      'bath': 0,
#      'car': 0,
#      'lat': 0,
#      'lng': 0,
#      'land': '263',
#      'sold_date': '2022-03-29',
#      'sold_price': 0,
#      'gnaf_pid': '',
#      'pu_id': 34866418156},
#     {'state': 'VIC',
#      'address': 'Address available on request',
#      'suburb_code': 'epping-vic-3076',
#      'suburb_name': 'Epping',
#      'postcode': '3076',
#      'image': 'https://farm66.static.flickr.com/65535/51967695701_d67d64edd9.jpg',
#      'type': 'residential land',
#      'bed': 0,
#      'bath': 0,
#      'car': 0,
#      'lat': 0,
#      'lng': 0,
#      'land': '243',
#      'sold_date': '2022-03-29',
#      'sold_price': 0,
#      'gnaf_pid': '',
#      'pu_id': 34887725056},
#     {'state': 'Vic',
#      'address': '23 HALPIN STREET',
#      'suburb_code': 'seymour-vic-3660',
#      'suburb_name': 'Seymour',
#      'postcode': '3660',
#      'image': 'https://farm66.static.flickr.com/65535/51968061389_e7e0f36134.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 2,
#      'car': 0,
#      'lat': -37.0273111,
#      'lng': 145.1483242,
#      'land': '',
#      'sold_date': '2022-03-29',
#      'sold_price': 500000,
#      'gnaf_pid': '',
#      'pu_id': 39789187030,
#      'agent_code': 'VIC185280',
#      'sold_price_display': '$470,000 - $490,000'},
#     {'state': 'VIC',
#      'address': '3 BED 2 BATH 2 CAR/3 Cotham Road',
#      'suburb_code': 'kew-vic-3101',
#      'suburb_name': 'Kew',
#      'postcode': '3101',
#      'image': 'https://farm66.static.flickr.com/65535/51966782347_759574f872.jpg',
#      'type': 'apartment',
#      'bed': 3,
#      'bath': 2,
#      'car': 2,
#      'lat': -37.8085832,
#      'lng': 145.0456673,
#      'land': '',
#      'sold_date': '2022-03-29',
#      'sold_price': 0,
#      'gnaf_pid': '',
#      'pu_id': 39717805827,
#      'agent_code': 'VIC348497'},
#     {'state': 'Vic',
#      'address': '9 Eldorado Loop',
#      'suburb_code': 'mernda-vic-3754',
#      'suburb_name': 'Mernda',
#      'postcode': '3754',
#      'image': 'https://farm66.static.flickr.com/65535/51968432630_6edf267cc2.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 2,
#      'car': 2,
#      'lat': -37.5903245,
#      'lng': 145.0802755,
#      'land': '424',
#      'sold_date': '2022-03-29',
#      'sold_price': 750000,
#      'gnaf_pid': '',
#      'pu_id': 39762924041,
#      'agent_code': 'VIC250993',
#      'sold_price_display': '$784,000 - $816,000'},
#     {'state': 'Vic',
#      'address': '6 Wilson Street',
#      'suburb_code': 'bonnie-doon-vic-3720',
#      'suburb_name': 'Bonnie Doon',
#      'postcode': '3720',
#      'image': 'https://farm66.static.flickr.com/65535/51968041004_f6f1202ac3.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 1,
#      'car': 4,
#      'lat': -37.0248166,
#      'lng': 145.8611474,
#      'land': '1213',
#      'sold_date': '2022-03-29',
#      'sold_price': 0,
#      'gnaf_pid': '',
#      'pu_id': 39776321610,
#      'agent_code': 'VIC80821'},
#     {'state': 'Vic',
#      'address': '3/135 DAWSON Street',
#      'suburb_code': 'sale-vic-3850',
#      'suburb_name': 'Sale',
#      'postcode': '3850',
#      'image': 'https://farm66.static.flickr.com/65535/51967927193_e0ff0e2bfd.jpg',
#      'type': 'unit',
#      'bed': 2,
#      'bath': 1,
#      'car': 1,
#      'lat': -38.0940745,
#      'lng': 147.073562,
#      'land': '',
#      'sold_date': '2022-03-29',
#      'sold_price': 305000,
#      'gnaf_pid': '',
#      'pu_id': 39766746041,
#      'agent_code': 'VIC16593',
#      'sold_price_display': '$313,000 - $327,000'},
#     {'state': 'Vic',
#      'address': '49 Sutherland  Street',
#      'suburb_code': 'kilmore-vic-3764',
#      'suburb_name': 'Kilmore',
#      'postcode': '3764',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQUWppVnkrRVVnU3YzWUlNd2p5aVFMY0U3aEozM3BUSkV6TzROQjJIRnltTm9QUUdLVXExRSt1em9MbER4Z3dicHIyV1FPNzE1bTFKM0VZQ0s4WGlKcmcyWXlheC9jd2xEVUkrM0RzS3ZTQ3lBPT0/preview.jpg',
#      'type': 'house',
#      'bed': 9,
#      'bath': 4,
#      'car': 0,
#      'lat': -37.305264,
#      'lng': 144.9471775,
#      'land': '16720',
#      'sold_date': '2022-03-29',
#      'sold_price': 3020000,
#      'gnaf_pid': '',
#      'pu_id': 39747323741,
#      'agent_code': 'VIC141250',
#      'sold_price_display': '$2,973,000 - $3,107,000'},
#     {'state': 'Vic',
#      'address': '21 Irving Road',
#      'suburb_code': 'cowes-vic-3922',
#      'suburb_name': 'Cowes',
#      'postcode': '3922',
#      'image': 'https://farm66.static.flickr.com/65535/51967844643_fec102b4fd.jpg',
#      'type': 'house',
#      'bed': 3,
#      'bath': 2,
#      'car': 3,
#      'lat': -38.4622872,
#      'lng': 145.2357866,
#      'land': '572',
#      'sold_date': '2022-03-29',
#      'sold_price': 790000,
#      'gnaf_pid': '',
#      'pu_id': 39732464720,
#      'agent_code': 'VIC1178',
#      'sold_price_display': '$739,000 - $769,000'},
#     {'state': 'VIC',
#      'address': '6 George Street',
#      'suburb_code': 'bunyip-vic-3815',
#      'suburb_name': 'Bunyip',
#      'postcode': '3815',
#      'image': 'https://farm66.static.flickr.com/65535/51968350655_620c0f7257.jpg',
#      'type': 'house',
#      'bed': 6,
#      'bath': 2,
#      'car': 8,
#      'lat': -38.097101,
#      'lng': 145.722069,
#      'land': '1587',
#      'sold_date': '2022-03-29',
#      'sold_price': 1180000,
#      'gnaf_pid': '',
#      'pu_id': 39787502751,
#      'agent_code': 'VIC305078',
#      'sold_price_display': '$1,148,000 - $1,204,000'},
#     {'state': 'VIC',
#      'address': '4 Roselands Court',
#      'suburb_code': 'langwarrin-vic-3910',
#      'suburb_name': 'Langwarrin',
#      'postcode': '3910',
#      'image': 'https://farm66.static.flickr.com/65535/51968072394_fe1dc62ff2.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 2,
#      'car': 2,
#      'lat': -38.15418,
#      'lng': 145.198445,
#      'land': '756',
#      'sold_date': '2022-03-29',
#      'sold_price': 1175000,
#      'gnaf_pid': '',
#      'pu_id': 39766588951,
#      'agent_code': 'VIC7517',
#      'sold_price_display': '$1,154,000 - $1,210,000'},
#     {'state': 'VIC',
#      'address': '65 Moxham Drive',
#      'suburb_code': 'kalkallo-vic-3064',
#      'suburb_name': 'Kalkallo',
#      'postcode': '3064',
#      'image': 'https://i7.auhouseprices.com/img/MmRXVnpmWkMwSXdtdjBPN2NEZUpkWk1SK1YrcDB2ajNUd2MwaTM5SzhQU05mWUFiS2c3TWZPdzdGWjhSQzNHWGVlaldwanM5TFVnTnpWUThyb2VSRDFDMXhnWmRWVDE3VElBdVJnMk12MDFGQzI2MFZ0cFdTZGhnS2JpamwrSjI1RGt5c3gxNHdKUVVVOXMxbUhJK2d3PT0/preview.jpg',
#      'type': 'house',
#      'bed': 5,
#      'bath': 4,
#      'car': 2,
#      'lat': -37.530434,
#      'lng': 144.9715541,
#      'land': '656',
#      'sold_date': '2022-03-29',
#      'sold_price': 1135000,
#      'gnaf_pid': '',
#      'pu_id': 39738748770,
#      'agent_code': 'VIC343788',
#      'sold_price_display': '$1,113,000 - $1,167,000'},
#     {'state': 'VIC',
#      'address': '89 Horizon Boulevard',
#      'suburb_code': 'greenvale-vic-3059',
#      'suburb_name': 'Greenvale',
#      'postcode': '3059',
#      'image': 'https://farm66.static.flickr.com/65535/51968075144_a6bd99fcf4.jpg',
#      'type': 'house',
#      'bed': 4,
#      'bath': 2,
#      'car': 3,
#      'lat': -37.6139677,
#      'lng': 144.888462,
#      'land': '511',
#      'sold_date': '2022-03-29',
#      'sold_price': 1130000,
#      'gnaf_pid': '',
#      'pu_id': 39707688841,
#      'agent_code': 'VIC313276',
#      'sold_price_display': '$1,110,000 - $1,164,000'},
#     {'state': 'VIC',
#      'address': '105 Sagars Road',
#      'suburb_code': 'hazelwood-north-vic-3840',
#      'suburb_name': 'Hazelwood North',
#      'postcode': '3840',
#      'image': 'https://farm66.static.flickr.com/65535/51967856708_9b4e2c81d0.jpg',
#      'type': 'house',
#      'bed': 5,
#      'bath': 2,
#      'car': 4,
#      'lat': -38.2918774,
#      'lng': 146.4946395,
#      'land': '20234',
#      'sold_date': '2022-03-29',
#      'sold_price': 875000,
#      'gnaf_pid': '',
#      'pu_id': 39753682610,
#      'agent_code': 'VIC340707',
#      'sold_price_display': '$825,000 - $857,000'}],
#    'meta': {'pagination': {'total': 155618,
#      'count': 50,
#      'per_page': 50,
#      'current_page': 1,
#      'total_pages': 3113,
#      'links': {'next': 'https://api2.aupropertyreport.com/api/state/vic/sold?page=2'}}}}}}
